# %% [markdown]
# # Introduction
#
# 在这节课中，我们将研究数据清理和探索性数据分析的过程。通常情况下，为了进行一些分析或回答一些问题，你会获得甚至得到一组数据。使用该数据的第一步是确保其格式正确(已清除)，并了解其属性和限制。在研究数据时，通常会确定在数据准备好进行分析之前可能需要的额外转换。
#
# In this notebook we obtain crime data from public records.  Ultimately, our goal might be to understand policing patterns but before we get there we must first clean and understand the data.

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # Getting the Data
#
# To begin this analysis we want to get data about crimes.  Remarkably, the city of Berkeley maintains an [Open Data Portal](https://data.cityofberkeley.info/) for citizens to access data about the city.  We will be examining the:
#
# 1. Call Data
# 1. Stop Data
#
# Fortunately, this data is also relatively well document with detailed descriptions of what it contains.  Here are summaries of the fields in the data:

# %% [markdown]
# **Calls Data**
# <img src="calls_desc.png" width=800px />

# %% [markdown]
# **Stop Data**
# <img src="stops_desc.png" width=800px />

# %% [markdown]
# ## Load Data Path
#
# ### `./路径`
# **<font color = red > 用相对路径就可以**

# %%
calls_file = "./data/calls_for_service.csv"

# %%
stops_file = "./data/stops.json"

# %% [markdown]
# ---
# How big is the data?
#
# ---
# 我通常喜欢通过粗略估计数据的大小来开始我的分析。这将有助于告知我使用的工具以及如何查看数据。如果它相对较小，我可能会使用文本编辑器或电子表格查看数据。如果它更大，我可能会跳转到更程序化的探索，甚至使用分布式计算工具。
#
# 不过，这里我们将使用python工具来探测该文件。

# %% [markdown]
# ### <font color = red >`os.path.getsize`

# %%
import os # 写在这儿了~
print(calls_file, "is",  os.path.getsize(calls_file) / 1e6, "MB")
print(stops_file, "is", os.path.getsize(stops_file) / 1e6, "MB")
# Out:
# ./data/calls_for_service.csv is 0.941358 MB
# ./data/stops.json is 17.134125 MB

# %% [markdown]
# All the files are relatively small and we could comfortable examine them in a text editors.  (Personally, I like *sublime*).
#
# In listing the files I noticed that the names suggest that they are all text file formats:
# * **CSV**: 逗号分隔值是一种非常标准的表格格式。
# * **JSON**: JavaScript对象表示法是一种非常标准的半结构化文件格式，用于存储嵌套数据。
#
# We will dive into the formats in a moment.  However because these are text data I might also want to investigate the number of lines which often correspond to records.

# %% [markdown]
# ### `with A as B`简写方法
# <font color = red >相当于R里的`attach-detach`

# %%
with open(calls_file, "r") as f:
    print(calls_file, "is", sum(1 for l in f), "lines.") # 有换行就考虑
# Out:
# ./data/calls_for_service.csv is 15452 lines.

# %% [markdown]
# ***
# Can we trust extensions?
# ***
# 我们已经注意到文件以csv和json结尾，这表明它们分别是用逗号分隔的和javascript对象文件。然而，我们不能总是依赖命名，因为这只是一种约定。例如，这里我们在下载时根据URL中的一些提示选择了文件的名称。
#
# **通常文件的扩展名不正确或者根本没有扩展名。**
#
# 让我们假设这些是文本文件(不包含二进制编码的数据)，因此我们可以打印“几行”以更好地理解该文件。

# %%
print(calls_file, "======================")
with open(calls_file, "r") as f: # 相当于R里的attach（xxx）
    for i in range(20):
        print(i, "\t", repr(f.readline())) # readline 只读一行
# Out:
# ./data/calls_for_service.csv ======================
# 0 	 'CASENO,OFFENSE,EVENTDT,EVENTTM,CVLEGEND,CVDOW,InDbDate,Block_Location,BLKADDR,City,State\n'
# 1 	 '19092769,THEFT MISD. (UNDER $950),12/09/2019 12:00:00 AM,13:00,LARCENY,1,09/10/2020 07:00:11 AM,"SHATTUCK AVE\n'
# 2 	 'Berkeley, CA",SHATTUCK AVE,Berkeley,CA\n'
# 3 	 '19045891,NARCOTICS,08/18/2019 12:00:00 AM,17:20,DRUG VIOLATION,0,09/10/2020 07:00:08 AM,"FRONTAGE STREET &GILMAN ST\n'
# 4 	 'Berkeley, CA",FRONTAGE STREET &GILMAN ST,Berkeley,CA\n'
# 5 	 '19060215,ASSAULT/BATTERY MISD.,10/23/2019 12:00:00 AM,10:45,ASSAULT,3,09/10/2020 07:00:10 AM,"2200 MILVIA ST\n'
# 6 	 'Berkeley, CA\n'
# 7 	 '(37.868574, -122.270415)",2200 MILVIA ST,Berkeley,CA\n'
# 8 	 '19092681,VANDALISM,12/01/2019 12:00:00 AM,18:40,VANDALISM,0,09/10/2020 07:00:11 AM,"VIRGINIA ST\n'
# 9 	 'Berkeley, CA",VIRGINIA ST,Berkeley,CA\n'
# 10 	 '19044228,ASSAULT/BATTERY MISD.,08/10/2019 12:00:00 AM,22:51,ASSAULT,6,09/10/2020 07:00:08 AM,"UNIVERSITY AVENUE &FRONTAGE\n'
# 11 	 'Berkeley, CA",UNIVERSITY AVENUE &FRONTAGE,Berkeley,CA\n'
# 12 	 '19092551,THEFT MISD. (UNDER $950),11/17/2019 12:00:00 AM,12:00,LARCENY,0,09/10/2020 07:00:11 AM,"ASHBY AVE\n'
# 13 	 'Berkeley, CA",ASHBY AVE,Berkeley,CA\n'
# 14 	 '19047517,BURGLARY AUTO,08/25/2019 12:00:00 AM,18:25,BURGLARY - VEHICLE,0,09/10/2020 07:00:08 AM,"CATALINA AVE\n'
# 15 	 'Berkeley, CA",CATALINA AVE,Berkeley,CA\n'
# 16 	 '19091711,VANDALISM,08/19/2019 12:00:00 AM,22:00,VANDALISM,1,09/10/2020 07:00:08 AM,"CALIFORNIA STREET & FAIRVIEW ST\n'
# 17 	 'Berkeley, CA",CALIFORNIA STREET & FAIRVIEW ST,Berkeley,CA\n'
# 18 	 '19092111,VANDALISM,09/24/2019 12:00:00 AM,20:00,VANDALISM,2,09/10/2020 07:00:09 AM,"600 CANYON RD\n'
# 19 	 'Berkeley, CA",600 CANYON RD,Berkeley,CA\n'

# %%
print(stops_file, "======================")
with open(stops_file, "r") as f:
    for i in range(20):
        print(i, "\t", repr(f.readline()))
# Out:
# ./data/stops.json ======================
# 0 	 '{\n'
# 1 	 '  "meta" : {\n'
# 2 	 '    "view" : {\n'
# 3 	 '      "id" : "4tbf-3yt8",\n'
# 4 	 '      "name" : "Berkeley PD - Stop Data (NEW)",\n'
# 5 	 '      "attribution" : "City of Berkeley Police Department",\n'
# 6 	 '      "averageRating" : 0,\n'
# 7 	 '      "category" : "Public Safety",\n'
# 8 	 '      "createdAt" : 1588602591,\n'
# 9 	 '      "description" : "This data was extracted from the Department鈥檚 Public Safety Server and covers data beginning January 26, 2015.  On January 26, 2015 the department began collecting data pursuant to General Order B-4 (issued December 31, 2014). Under that Order, officers were required to provide certain data after making any detention (vehicle, bicycle, pedestrian, suspicious auto).  This dataset provides information about detentions, including the race, sex, age range, of the person detained; the reason for the stop; the type of enforcement taken (if any), and whether or not a search was conducted.  Also provided are the date, time, location of the detention, as well as the incident number and call for service type.",\n'
# 10 	 '      "displayType" : "table",\n'
# 11 	 '      "downloadCount" : 48,\n'
# 12 	 '      "hideFromCatalog" : false,\n'
# 13 	 '      "hideFromDataJson" : false,\n'
# 14 	 '      "licenseId" : "USGOV_WORKS",\n'
# 15 	 '      "newBackend" : true,\n'
# 16 	 '      "numberOfComments" : 0,\n'
# 17 	 '      "oid" : 34059901,\n'
# 18 	 '      "provenance" : "official",\n'
# 19 	 '      "publicationAppendEnabled" : false,\n'

# %% [markdown]
# 注意，我使用了`repr`函数返回带有特殊字符的原始字符串。这对推断文件格式很有帮助。

# %% [markdown]
# ***
# What are some observations about `Calls` data?
# ***
# 1. It appears to be in comma separated value (CSV) format.
# 1. First line contains the column headings.
# 1. There are lots of **new-line** `\n` characters:
#     * at the ends of lines (delimiting records?)
#     * *within records* as part of addresses.
# 1. There are **"quoted"** strings in the `Block_Location` column:
# ```
# "SHATTUCK AVE\n'
# 2 	 'Berkeley, CA"
# ```
# these are going to be difficult.  What are the implications on our earlier line count calculations?

# %% [markdown]
# ### JSON文件
#
# 这似乎是一个相当标准的JSON文件。我们注意到，该文件在一个名为`meta`(大概是元数据的缩写)的字段中似乎包含了对自身的描述。让我们快速讨论一下JSON文件格式。

# %% [markdown]
# [JSON (JavaScript Object Notation)](http://www.json.org) is a common format for exchanging complex structured and semi-structured data.
#
#
# ```javascript
# {
#     "field1": "value1",
#     "field2": ["list", "of", "values"],
#     "myfield3": {"is_recursive": true, "a null value": null}
# }
# ```
#
# A few key points:
# * JSON is a recursive format in that JSON fields can also contain JSON objects
# * JSON closely matches Python Dictionaries:
# ```python
# d = {
#     "field1": "value1",
#     "field2": ["list", "of", "values"],
#     "myfield3": {"is_recursive": True, "a null value": None}
# }
# print(d['myfield3'])
# ```
# * Very common in web technologies (... JavaScript)
# * Many languages have tools for loading and saving JSON objects

# %% [markdown]
# ***
# Loading the Data
# ***
# 现在我们将尝试将数据加载到python中。我们将使用Pandas数据帧库进行基本的表格数据分析。
#
# 幸运的是，Pandas库有一些相对复杂的用于加载数据的函数。

# %% [markdown]
# ### 检查dataframe
# `calls.head()
# calls.shape
# calls.dtypes)`
#
# 因为该文件看起来是一个格式相对良好的CSV，我们将尝试直接加载它，并允许Pandas Library推断列标题。
#
# **你在加载后总是检查第一行和列是否正确。**

# %%
calls = pd.read_csv(calls_file)
print("Check data ===========================\n",calls.head()) # 检查数据格式
print("\nData shape ===========================\n",calls.shape) # 行列
print("\nData type ===========================\n",calls.dtypes) # 类型
# Out:
# Check data ===========================
#       CASENO                   OFFENSE                 EVENTDT EVENTTM  \
# 0  19092769  THEFT MISD. (UNDER $950)  12/09/2019 12:00:00 AM   13:00
# 1  19045891                 NARCOTICS  08/18/2019 12:00:00 AM   17:20
# 2  19060215     ASSAULT/BATTERY MISD.  10/23/2019 12:00:00 AM   10:45
# 3  19092681                 VANDALISM  12/01/2019 12:00:00 AM   18:40
# 4  19044228     ASSAULT/BATTERY MISD.  08/10/2019 12:00:00 AM   22:51
#
#          CVLEGEND  CVDOW                InDbDate  \
# 0         LARCENY      1  09/10/2020 07:00:11 AM
# 1  DRUG VIOLATION      0  09/10/2020 07:00:08 AM
# 2         ASSAULT      3  09/10/2020 07:00:10 AM
# 3       VANDALISM      0  09/10/2020 07:00:11 AM
# 4         ASSAULT      6  09/10/2020 07:00:08 AM
#
#                                       Block_Location  \
# 0                         SHATTUCK AVE\nBerkeley, CA
# 1           FRONTAGE STREET &GILMAN ST\nBerkeley, CA
# 2  2200 MILVIA ST\nBerkeley, CA\n(37.868574, -122...
# 3                          VIRGINIA ST\nBerkeley, CA
# 4          UNIVERSITY AVENUE &FRONTAGE\nBerkeley, CA
#
#                        BLKADDR      City State
# 0                 SHATTUCK AVE  Berkeley    CA
# 1   FRONTAGE STREET &GILMAN ST  Berkeley    CA
# 2               2200 MILVIA ST  Berkeley    CA
# 3                  VIRGINIA ST  Berkeley    CA
# 4  UNIVERSITY AVENUE &FRONTAGE  Berkeley    CA
#
# Data shape ===========================
#  (5227, 11)
#
# Data type ===========================
#  CASENO             int64
# OFFENSE           object
# EVENTDT           object
# EVENTTM           object
# CVLEGEND          object
# CVDOW              int64
# InDbDate          object
# Block_Location    object
# BLKADDR           object
# City              object
# State             object
# dtype: object

# %%
calls
# Out:
#         CASENO                   OFFENSE                 EVENTDT EVENTTM  \
# 0     19092769  THEFT MISD. (UNDER $950)  12/09/2019 12:00:00 AM   13:00
# 1     19045891                 NARCOTICS  08/18/2019 12:00:00 AM   17:20
# 2     19060215     ASSAULT/BATTERY MISD.  10/23/2019 12:00:00 AM   10:45
# 3     19092681                 VANDALISM  12/01/2019 12:00:00 AM   18:40
# 4     19044228     ASSAULT/BATTERY MISD.  08/10/2019 12:00:00 AM   22:51
# ...        ...                       ...                     ...     ...
# 5222  19092686             BURGLARY AUTO  12/02/2019 12:00:00 AM   08:30
# 5223  19043965  THEFT MISD. (UNDER $950)  08/05/2019 12:00:00 AM   23:30
# 5224  19052923             BURGLARY AUTO  09/19/2019 12:00:00 AM   13:30
# 5225  19049410               DISTURBANCE  08/05/2019 12:00:00 AM   10:00
# 5226  19092182             BURGLARY AUTO  10/10/2019 12:00:00 AM   09:55
#
#                 CVLEGEND  CVDOW                InDbDate  \
# 0                LARCENY      1  09/10/2020 07:00:11 AM
# 1         DRUG VIOLATION      0  09/10/2020 07:00:08 AM
# 2                ASSAULT      3  09/10/2020 07:00:10 AM
# 3              VANDALISM      0  09/10/2020 07:00:11 AM
# 4                ASSAULT      6  09/10/2020 07:00:08 AM
# ...                  ...    ...                     ...
# 5222  BURGLARY - VEHICLE      1  09/10/2020 07:00:11 AM
# 5223             LARCENY      1  09/10/2020 07:00:08 AM
# 5224  BURGLARY - VEHICLE      4  09/10/2020 07:00:09 AM
# 5225  DISORDERLY CONDUCT      1  09/10/2020 07:00:09 AM
# 5226  BURGLARY - VEHICLE      4  09/10/2020 07:00:10 AM
#
#                                          Block_Location  \
# 0                            SHATTUCK AVE\nBerkeley, CA
# 1              FRONTAGE STREET &GILMAN ST\nBerkeley, CA
# 2     2200 MILVIA ST\nBerkeley, CA\n(37.868574, -122...
# 3                             VIRGINIA ST\nBerkeley, CA
# 4             UNIVERSITY AVENUE &FRONTAGE\nBerkeley, CA
# ...                                                 ...
# 5222  1000 GILMAN ST\nBerkeley, CA\n(37.88014, -122....
# 5223  2300 WARD ST\nBerkeley, CA\n(37.860105, -122.2...
# 5224  1500 SHATTUCK AV\nBerkeley, CA\n(37.880227, -1...
# 5225  2900 REGENT ST\nBerkeley, CA\n(37.857787, -122...
# 5226  1500 SHATTUCK AV\nBerkeley, CA\n(37.880227, -1...
#
#                           BLKADDR      City State
# 0                    SHATTUCK AVE  Berkeley    CA
# 1      FRONTAGE STREET &GILMAN ST  Berkeley    CA
# 2                  2200 MILVIA ST  Berkeley    CA
# 3                     VIRGINIA ST  Berkeley    CA
# 4     UNIVERSITY AVENUE &FRONTAGE  Berkeley    CA
# ...                           ...       ...   ...
# 5222               1000 GILMAN ST  Berkeley    CA
# 5223                 2300 WARD ST  Berkeley    CA
# 5224             1500 SHATTUCK AV  Berkeley    CA
# 5225               2900 REGENT ST  Berkeley    CA
# 5226             1500 SHATTUCK AV  Berkeley    CA
#
# [5227 rows x 11 columns]

# %% [markdown]
# ***
# Preliminary observations on the data?
# ***

# %% [markdown]
# 1. `EVENTDT` -- Contain the incorrect time stamp
# 1. `EVENTTM` -- Contains the time in 24 hour format
# 1. `CVDOW` -- Appears to be some encoding of the day of the week (see data documentation).
# 1. `InDbDate` -- Appears to be correctly formatted and appears pretty consistent in time.
# 1. **`Block_Location` -- Errr, what a mess!  newline characters, and Geocoordinates all merged!!  Fortunately, this field was "quoted" otherwise we would have had trouble parsing the file. (why?)**
# 1. `BLKADDR` -- This appears to be the address in Block Location.
# 1. `City` and `State` seem redundant given this is supposed to be the city of Berkeley dataset.

# %% [markdown]
# ### Pivot Table
#
# Checking that the City and State fields are all Berkeley CA
#
# 我们注意到有城市列和州列。因为这应该是伯克利市的数据，**这些列似乎是多余的**。让我们快速计算这两列出现唯一值的次数。

# %%
calls.groupby(["State", "City"]).count()
# Out:
#                 CASENO  OFFENSE  EVENTDT  EVENTTM  CVLEGEND  CVDOW  InDbDate  \
# State City
# CA    Berkeley    5227     5227     5227     5227      5227   5227      5227
#
#                 Block_Location  BLKADDR
# State City
# CA    Berkeley            5227     5190

# %% [markdown]
# ### Dataframe 数据替换

# %% [markdown]
# #### `map()`数据替换

# %%
dow = {0:"Sunday", 1:"Monday", 2:"Tuesday", 
       3:"Wednesday", 4:"Thursday", 5:"Friday", 
       6:"Saturday"}
dow
# Out:
# {0: 'Sunday',
#  1: 'Monday',
#  2: 'Tuesday',
#  3: 'Wednesday',
#  4: 'Thursday',
#  5: 'Friday',
#  6: 'Saturday'}

# %%
calls["Day"] = calls["CVDOW"].map(dow)
# equal to: calls.loc[:,"Day"] = calls.loc[:,"CVDOW"].map(dow)
calls[["Day","CVDOW"]]
# Out:
#             Day  CVDOW
# 0        Monday      1
# 1        Sunday      0
# 2     Wednesday      3
# 3        Sunday      0
# 4      Saturday      6
# ...         ...    ...
# 5222     Monday      1
# 5223     Monday      1
# 5224   Thursday      4
# 5225     Monday      1
# 5226   Thursday      4
#
# [5227 rows x 2 columns]

# %% [markdown]
# ***
# 补充，画出计数折线图
# ***

# %%
calls["Day"] = calls["CVDOW"].map(dow)
# equal to: calls.loc[:,"Day"] = calls.loc[:,"CVDOW"].map(dow)
calls[a["Day","CVDOW"]].groupby('Day').count().plot()
# Out:
# <AxesSubplot:xlabel='Day'>

# %% [markdown]
# ### Cleaning Block Location
#
# 块位置包含纬度/经度坐标，我可能想使用这些来分析每个请求的位置。让我们尝试使用正则表达式提取GPS坐标(我们将在以后的课程中讨论正则表达式):

# %%
calls['Block_Location'].head(10)
# Out:
# 0                           SHATTUCK AVE\nBerkeley, CA
# 1             FRONTAGE STREET &GILMAN ST\nBerkeley, CA
# 2    2200 MILVIA ST\nBerkeley, CA\n(37.868574, -122...
# 3                            VIRGINIA ST\nBerkeley, CA
# 4            UNIVERSITY AVENUE &FRONTAGE\nBerkeley, CA
# 5                              ASHBY AVE\nBerkeley, CA
# 6                           CATALINA AVE\nBerkeley, CA
# 7        CALIFORNIA STREET & FAIRVIEW ST\nBerkeley, CA
# 8                          600 CANYON RD\nBerkeley, CA
# 9    1700 FOURTH ST\nBerkeley, CA\n(37.871883, -122...
# Name: Block_Location, dtype: object

# %%
# 字符串处理：split 返回split后的list
s = 'Nina ( North ) Kristen Scott'
s.split("(")[1].split(")")[0]
# Out:
# ' North '

# %%
def get_lat_lon(s):
    try:
        return s.split("(")[1].split(")")[0]
    except:
        return np.nan

calls_lat_lon = calls['Block_Location'].apply(get_lat_lon) # map 也可以！
calls_lat_lon.head(10)
# Out:
# 0                       NaN
# 1                       NaN
# 2    37.868574, -122.270415
# 3                       NaN
# 4                       NaN
# 5                       NaN
# 6                       NaN
# 7                       NaN
# 8                       NaN
# 9    37.871883, -122.301255
# Name: Block_Location, dtype: object

# %%
# 正则表达式
# pandas method
calls_lat_lon = (
    # Remove newlines
    calls['Block_Location'].str.replace("\n", "\t") 
    # Extract Lat and Lon using regular expression
    .str.extract(".*\((?P<Lat>\d*\.\d*)\, (?P<Lon>-?\d*\.\d*)\)", expand=True)
)
calls_lat_lon.head(10)
# Out:
#          Lat          Lon
# 0        NaN          NaN
# 1        NaN          NaN
# 2  37.868574  -122.270415
# 3        NaN          NaN
# 4        NaN          NaN
# 5        NaN          NaN
# 6        NaN          NaN
# 7        NaN          NaN
# 8        NaN          NaN
# 9  37.871883  -122.301255

# %% [markdown]
# #### `~`求反运算
# 计算数据比例： “~”求反运算 !

# %%
# Not all the records have a lat and lon. What fraction do have coordinates?
(~calls_lat_lon.isnull()).mean()
# Out:
# Lat    0.963076
# Lon    0.963076
# dtype: float64

# %% [markdown]
# <br/><br/><br/>
#
#
# ---
# ## 导入`json`:open(json)
# **<font color = darkred>导入为字典。**

# %% [markdown]
# Python对JSON数据的支持相对较好，因为它与内部Python对象模型非常匹配。在下面的单元格中，我们将整个JSON数据文件导入到python字典中。

# %%
import json

with open("data/stops.json", "rb") as f: # 用 f 代替 open("data/stops.json", "rb")
    stops_json = json.load(f)

# %% [markdown]
# `stops_json`变量现在是一个编码文件中的数据的字典:

# %%
type(stops_json)
# Out:
# {'meta': {'view': {'id': '4tbf-3yt8',
#    'name': 'Berkeley PD - Stop Data (NEW)',
#    'attribution': 'City of Berkeley Police Department',
#    'averageRating': 0,
#    'category': 'Public Safety',
#    'createdAt': 1588602591,
#    'description': 'This data was extracted from the Department’s Public Safety Server and covers data beginning January 26, 2015.  On January 26, 2015 the department began collecting data pursuant to General Order B-4 (issued December 31, 2014). Under that Order, officers were required to provide certain data after making any detention (vehicle, bicycle, pedestrian, suspicious auto).  This dataset provides information about detentions, including the race, sex, age range, of the person detained; the reason for the stop; the type of enforcement taken (if any), and whether or not a search was conducted.  Also provided are the date, time, location of the detention, as well as the incident number and call for service type.',
#    'displayType': 'table',
#    'downloadCount': 48,
#    'hideFromCatalog': False,
#    'hideFromDataJson': False,
#    'licenseId': 'USGOV_WORKS',
#    'newBackend': True,
#    'numberOfComments': 0,
#    'oid': 34059901,
#    'provenance': 'official',
#    'publicationAppendEnabled': False,
#    'publicationDate': 1588604692,
#    'publicationGroup': 17089931,
#    'publicationStage': 'published',
#    'rowsUpdatedAt': 1599210021,
#    'rowsUpdatedBy': '3qfy-i8ke',
#    'tableId': 17089931,
#    'totalTimesRated': 0,
#    'viewCount': 568,
#    'viewLastModified': 1591988483,
#    'viewType': 'tabular',
#    'approvals': [{'reviewedAt': 1591994053,
#      'reviewedAutomatically': True,
#      'state': 'approved',
#      'submissionId': 2312922,
#      'submissionObject': 'public_audience_request',
#      'submissionOutcome': 'change_audience',
#      'submittedAt': 1591994053,
#      'workflowId': 2114,
#      'submissionDetails': {'permissionType': 'READ'},
#      'submissionOutcomeApplication': {'endedAt': 1591994054,
#       'failureCount': 0,
#       'startedAt': 1591994053,
#       'status': 'success'},
#      'submitter': {'id': 'tqdh-nm3t', 'displayName': 'Police'}}],
#    'columns': [{'id': -1,
#      'name': 'sid',
#      'dataTypeName': 'meta_data',
#      'fieldName': ':sid',
#      'position': 0,
#      'renderTypeName': 'meta_data',
#      'format': {},
#      'flags': ['hidden']},
#     {'id': -1,
#      'name': 'id',
#      'dataTypeName': 'meta_data',
#      'fieldName': ':id',
#      'position': 0,
#      'renderTypeName': 'meta_data',
#      'format': {},
#      'flags': ['hidden']},
#     {'id': -1,
#      'name': 'position',
#      'dataTypeName': 'meta_data',
#      'fieldName': ':position',
#      'position': 0,
#      'renderTypeName': 'meta_data',
#      'format': {},
#      'flags': ['hidden']},
#     {'id': -1,
#      'name': 'created_at',
#      'dataTypeName': 'meta_data',
#      'fieldName': ':created_at',
#      'position': 0,
#      'renderTypeName': 'meta_data',
#      'format': {},
#      'flags': ['hidden']},
#     {'id': -1,
#      'name': 'created_meta',
#      'dataTypeName': 'meta_data',
#      'fieldName': ':created_meta',
#      'position': 0,
#      'renderTypeName': 'meta_data',
#      'format': {},
#      'flags': ['hidden']},
#     {'id': -1,
#      'name': 'updated_at',
#      'dataTypeName': 'meta_data',
#      'fieldName': ':updated_at',
#      'position': 0,
#      'renderTypeName': 'meta_data',
#      'format': {},
#      'flags': ['hidden']},
#     {'id': -1,
#      'name': 'updated_meta',
#      'dataTypeName': 'meta_data',
#      'fieldName': ':updated_meta',
#      'position': 0,
#      'renderTypeName': 'meta_data',
#      'format': {},
#      'flags': ['hidden']},
#     {'id': -1,
#      'name': 'meta',
#      'dataTypeName': 'meta_data',
#      'fieldName': ':meta',
#      'position': 0,
#      'renderTypeName': 'meta_data',
#      'format': {},
#      'flags': ['hidden']},
#     {'id': 465602715,
#      'name': 'CreateDatetime',
#      'dataTypeName': 'calendar_date',
#      'description': '',
#      'fieldName': 'createdatetime',
#      'position': 1,
#      'renderTypeName': 'calendar_date',
#      'tableColumnId': 100610693,
#      'width': 187,
#      'cachedContents': {'non_null': '58718',
#       'largest': '2020-09-02T09:28:30.000',
#       'null': '0',
#       'top': [{'item': '2015-06-11T06:48:26.000', 'count': '10'},
#        {'item': '2020-02-13T08:10:43.000', 'count': '6'},
#        {'item': '2017-01-26T11:10:06.000', 'count': '6'},
#        {'item': '2020-01-07T08:15:40.000', 'count': '6'},
#        {'item': '2016-07-03T23:45:04.000', 'count': '5'},
#        {'item': '2015-02-01T19:33:13.000', 'count': '5'},
#        {'item': '2016-06-11T19:55:36.000', 'count': '5'},
#        {'item': '2015-11-16T07:19:28.000', 'count': '5'},
#        {'item': '2016-04-19T00:50:19.000', 'count': '5'},
#        {'item': '2016-03-25T01:13:14.000', 'count': '5'},
#        {'item': '2017-01-06T00:25:16.000', 'count': '5'},
#        {'item': '2016-12-22T23:58:59.000', 'count': '5'},
#        {'item': '2016-07-19T02:51:56.000', 'count': '4'},
#        {'item': '2015-11-09T22:17:36.000', 'count': '4'},
#        {'item': '2015-12-19T02:11:34.000', 'count': '4'},
#        {'item': '2016-07-21T02:03:22.000', 'count': '4'},
#        {'item': '2017-06-29T02:15:29.000', 'count': '4'},
#        {'item': '2018-07-02T21:36:29.000', 'count': '4'},
#        {'item': '2016-05-25T01:20:06.000', 'count': '4'},
#        {'item': '2016-05-01T01:23:53.000', 'count': '4'}],
#       'smallest': '2015-01-26T07:16:06.000',
#       'cardinality': '56774'},
#      'format': {}},
#     {'id': 465602716,
#      'name': 'IncidentNumber',
#      'dataTypeName': 'text',
#      'description': '',
#      'fieldName': 'incidentnumber',
#      'position': 2,
#      'renderTypeName': 'text',
#      'tableColumnId': 100610694,
#      'width': 145,
#      'cachedContents': {'non_null': '58711',
#       'largest': '2020-00040735',
#       'null': '7',
#       'top': [{'item': '2020-00001049', 'count': '6'},
#        {'item': '2020-00008547', 'count': '6'},
#        {'item': '2015-00033565', 'count': '5'},
#        {'item': '2016-00039405', 'count': '5'},
#        {'item': '2016-00017339', 'count': '5'},
#        {'item': '2016-00075241', 'count': '5'},
#        {'item': '2016-00034574', 'count': '5'},
#        {'item': '2017-00000828', 'count': '5'},
#        {'item': '2015-00033576', 'count': '5'},
#        {'item': '2015-00067321', 'count': '5'},
#        {'item': '2015-00006347', 'count': '5'},
#        {'item': '2016-00022806', 'count': '5'},
#        {'item': '2016-00030608', 'count': '4'},
#        {'item': '2019-00025759', 'count': '4'},
#        {'item': '2016-00049625', 'count': '4'},
#        {'item': '2018-00010987', 'count': '4'},
#        {'item': '2015-00033137', 'count': '4'},
#        {'item': '2017-00045853', 'count': '4'},
#        {'item': '2016-00042412', 'count': '4'},
#        {'item': '2017-00057823', 'count': '4'}],
#       'smallest': '2015-00004848',
#       'cardinality': '56787'},
#      'format': {}},
#     {'id': 465602721,
#      'name': 'Address',
#      'dataTypeName': 'text',
#      'description': '',
#      'fieldName': 'address',
#      'position': 3,
#      'renderTypeName': 'text',
#      'tableColumnId': 100610699,
#      'cachedContents': {'non_null': '57069',
#       'largest': 'YALE AVE/RUGBY AVE',
#       'null': '1649',
#       'top': [{'item': 'UNIVERSITY AVE / 6TH ST', 'count': '525'},
#        {'item': 'UNIVERSITY AVE / SAN PABLO AVE', 'count': '472'},
#        {'item': 'ASHBY AVE / 7TH ST', 'count': '449'},
#        {'item': '6TH ST / UNIVERSITY AVE', 'count': '449'},
#        {'item': '7TH ST / POTTER ST', 'count': '372'},
#        {'item': 'UNIVERSITY AVE / MARTIN LUTHER KING JR WAY', 'count': '360'},
#        {'item': 'ASHBY AVE / SAN PABLO AVE', 'count': '351'},
#        {'item': '80 BOLIVAR DR', 'count': '349'},
#        {'item': 'SAN PABLO AVE / UNIVERSITY AVE', 'count': '340'},
#        {'item': 'UNIVERSITY AVE / FRONTAGE RD', 'count': '320'},
#        {'item': '7TH ST / ASHBY AVE', 'count': '311'},
#        {'item': 'UNIVERSITY AVE / ACTON ST', 'count': '296'},
#        {'item': 'UNIVERSITY AVE / SACRAMENTO ST', 'count': '295'},
#        {'item': 'SHATTUCK AVE / KITTREDGE ST', 'count': '272'},
#        {'item': 'UNIVERSITY AVE / BONAR ST', 'count': '242'},
#        {'item': 'SAN PABLO AVE / ASHBY AVE', 'count': '231'},
#        {'item': 'POTTER ST / 7TH ST', 'count': '217'},
#        {'item': 'UNIVERSITY AVE / 7TH ST', 'count': '214'},
#        {'item': '1998 SHATTUCK AVE', 'count': '211'},
#        {'item': 'UNIVERSITY AVE / SHATTUCK AVE', 'count': '204'}],
#       'smallest': '1000 63RD ST',
#       'cardinality': '6449'},
#      'format': {}},
#     {'id': 465602717,
#      'name': 'City',
#      'dataTypeName': 'text',
#      'description': '',
#      'fieldName': 'city',
#      'position': 4,
#      'renderTypeName': 'text',
#      'tableColumnId': 100610695,
#      'width': 139,
#      'cachedContents': {'non_null': '55325',
#       'largest': 'OAKLAND',
#       'null': '3393',
#       'top': [{'item': 'BERKELEY', 'count': '53060'},
#        {'item': 'OAKLAND', 'count': '1818'},
#        {'item': 'EMERYVILLE', 'count': '316'},
#        {'item': 'ALBANY', 'count': '129'},
#        {'item': 'Berkeley', 'count': '2'}],
#       'smallest': 'ALBANY',
#       'cardinality': '5'},
#      'format': {}},
#     {'id': 465602713,
#      'name': 'Lat',
#      'dataTypeName': 'number',
#      'description': '',
#      'fieldName': 'lat',
#      'position': 5,
#      'renderTypeName': 'number',
#      'tableColumnId': 100610691,
#      'width': 155,
#      'cachedContents': {'non_null': '58718',
#       'largest': '37.904304888',
#       'null': '0',
#       'top': [{'item': '-361', 'count': '2958'},
#        {'item': '37.867993895', 'count': '974'},
#        {'item': '37.869096588', 'count': '812'},
#        {'item': '37.851008554', 'count': '760'},
#        {'item': '37.851514871', 'count': '589'},
#        {'item': '37.852140636', 'count': '582'},
#        {'item': '37.871555258', 'count': '500'},
#        {'item': '37.870410562', 'count': '410'},
#        {'item': '37.868489249', 'count': '396'},
#        {'item': '37.872151446', 'count': '394'},
#        {'item': '37.866444425', 'count': '392'},
#        {'item': '37.853281083', 'count': '355'},
#        {'item': '37.870112645', 'count': '349'},
#        {'item': '37.864546214', 'count': '349'},
#        {'item': '37.868202006', 'count': '335'},
#        {'item': '37.854316382', 'count': '335'},
#        {'item': '37.851615813', 'count': '311'},
#        {'item': '37.8693028530001', 'count': '289'},
#        {'item': '37.865779797', 'count': '269'},
#        {'item': '37.869696081', 'count': '265'}],
#       'smallest': '-361',
#       'cardinality': '3204'},
#      'format': {}},
#     {'id': 465602722,
#      'name': 'Lon',
#      'dataTypeName': 'number',
#      'description': '',
#      'fieldName': 'lon',
#      'position': 6,
#      'renderTypeName': 'number',
#      'tableColumnId': 100610700,
#      'width': 150,
#      'cachedContents': {'non_null': '58718',
#       'largest': '-121.765272953',
#       'null': '0',
#       'top': [{'item': '-361', 'count': '2958'},
#        {'item': '-122.297664389', 'count': '974'},
#        {'item': '-122.292119433', 'count': '812'},
#        {'item': '-122.291104028', 'count': '760'},
#        {'item': '-122.291270411', 'count': '589'},
#        {'item': '-122.286683357', 'count': '582'},
#        {'item': '-122.273001335', 'count': '500'},
#        {'item': '-122.281937988', 'count': '410'},
#        {'item': '-122.267867519', 'count': '396'},
#        {'item': '-122.26841392', 'count': '394'},
#        {'item': '-122.305556167', 'count': '392'},
#        {'item': '-122.279011568', 'count': '355'},
#        {'item': '-122.301738812', 'count': '349'},
#        {'item': '-122.284248929', 'count': '349'},
#        {'item': '-122.29662475', 'count': '335'},
#        {'item': '-122.271084145', 'count': '335'},
#        {'item': '-122.289369289', 'count': '311'},
#        {'item': '-122.272234021', 'count': '289'},
#        {'item': '-122.267576002', 'count': '269'},
#        {'item': '-122.287499477', 'count': '265'}],
#       'smallest': '-361',
#       'cardinality': '3204'},
#      'format': {}},
#     {'id': 465602714,
#      'name': 'CallType',
#      'dataTypeName': 'text',
#      'description': '',
#      'fieldName': 'calltype',
#      'position': 7,
#      'renderTypeName': 'text',
#      'tableColumnId': 100610692,
#      'width': 103,
#      'cachedContents': {'non_null': '58718',
#       'largest': 'T',
#       'null': '0',
#       'top': [{'item': 'T', 'count': '46101'},
#        {'item': '1194', 'count': '6873'},
#        {'item': '1196', 'count': '3247'},
#        {'item': '1194B', 'count': '2497'}],
#       'smallest': '1194',
#       'cardinality': '4'},
#      'format': {}},
#     {'id': 465602718,
#      'name': 'Race',
#      'dataTypeName': 'text',
#      'description': '',
#      'fieldName': 'race',
#      'position': 8,
#      'renderTypeName': 'text',
#      'tableColumnId': 100610696,
#      'width': 83,
#      'cachedContents': {'non_null': '58718',
#       'largest': 'White',
#       'null': '0',
#       'top': [{'item': 'White', 'count': '20544'},
#        {'item': 'Black', 'count': '19776'},
#        {'item': 'Hispanic', 'count': '7534'},
#        {'item': 'Other', 'count': '5885'},
#        {'item': 'Asian', 'count': '4621'},
#        {'item': '0', 'count': '358'}],
#       'smallest': '0',
#       'cardinality': '6'},
#      'format': {}},
#     {'id': 465602724,
#      'name': 'Gender',
#      'dataTypeName': 'text',
#      'description': '',
#      'fieldName': 'gender',
#      'position': 9,
#      'renderTypeName': 'text',
#      'tableColumnId': 100610702,
#      'width': 88,
#      'cachedContents': {'non_null': '58718',
#       'largest': 'Male',
#       'null': '0',
#       'top': [{'item': 'Male', 'count': '41115'},
#        {'item': 'Female', 'count': '17245'},
#        {'item': '0', 'count': '358'}],
#       'smallest': '0',
#       'cardinality': '3'},
#      'format': {}},
#     {'id': 465602725,
#      'name': 'Age',
#      'dataTypeName': 'text',
#      'description': '',
#      'fieldName': 'age',
#      'position': 10,
#      'renderTypeName': 'text',
#      'tableColumnId': 100610703,
#      'width': 114,
#      'cachedContents': {'non_null': '58718',
#       'largest': '>40',
#       'null': '0',
#       'top': [{'item': '>40', 'count': '21829'},
#        {'item': '18-29', 'count': '19276'},
#        {'item': '30-39', 'count': '15822'},
#        {'item': '<18', 'count': '1433'},
#        {'item': '0', 'count': '358'}],
#       'smallest': '0',
#       'cardinality': '5'},
#      'format': {}},
#     {'id': 465602720,
#      'name': 'Reason',
#      'dataTypeName': 'text',
#      'description': '',
#      'fieldName': 'reason',
#      'position': 11,
#      'renderTypeName': 'text',
#      'tableColumnId': 100610698,
#      'width': 111,
#      'cachedContents': {'non_null': '58714',
#       'largest': 'Wanted',
#       'null': '4',
#       'top': [{'item': 'Traffic', 'count': '49525'},
#        {'item': 'Investigation', 'count': '5329'},
#        {'item': 'Reas. Susp.', 'count': '2307'},
#        {'item': 'Prob./Parole', 'count': '984'},
#        {'item': '0', 'count': '358'},
#        {'item': 'Wanted', 'count': '211'}],
#       'smallest': '0',
#       'cardinality': '6'},
#      'format': {}},
#     {'id': 465602723,
#      'name': 'Enforcement',
#      'dataTypeName': 'text',
#      'description': '',
#      'fieldName': 'enforcement',
#      'position': 12,
#      'renderTypeName': 'text',
#      'tableColumnId': 100610701,
#      'width': 117,
#      'cachedContents': {'non_null': '58718',
#       'largest': 'Warning',
#       'null': '0',
#       'top': [{'item': 'Warning', 'count': '35217'},
#        {'item': 'Citation', 'count': '20262'},
#        {'item': 'Arrest', 'count': '1930'},
#        {'item': 'Other', 'count': '951'},
#        {'item': '0', 'count': '358'}],
#       'smallest': '0',
#       'cardinality': '5'},
#      'format': {}},
#     {'id': 465602719,
#      'name': 'Car Search',
#      'dataTypeName': 'text',
#      'description': '',
#      'fieldName': 'car_search',
#      'position': 13,
#      'renderTypeName': 'text',
#      'tableColumnId': 100610697,
#      'width': 123,
#      'cachedContents': {'non_null': '58718',
#       'largest': 'Search',
#       'null': '0',
#       'top': [{'item': 'No Search', 'count': '49500'},
#        {'item': 'Search', 'count': '8860'},
#        {'item': '0', 'count': '358'}],
#       'smallest': '0',
#       'cardinality': '3'},
#      'format': {}}],
#    'grants': [{'inherited': False, 'type': 'viewer', 'flags': ['public']}],
#    'license': {'name': 'Public Domain U.S. Government',
#     'termsLink': 'https://www.usa.gov/government-works'},
#    'metadata': {'jsonQuery': {'order': [{'columnFieldName': 'createdatetime',
#        'ascending': False}]},
#     'attachments': [{'filename': 'Berkeley Stop Data.pdf',
#       'assetId': '2ed1e25d-effc-4e3f-b74c-21599b22b85f',
#       'name': 'Berkeley Stop Data.pdf'}],
#     'custom_fields': {'Required fields': {'One Page Narrative': 'Please see attachment.'}},
#     'rowLabel': 'Row',
#     'availableDisplayTypes': ['table', 'fatrow', 'page'],
#     'renderTypeConfig': {'visible': {'table': True}}},
#    'owner': {'id': 'tqdh-nm3t',
#     'displayName': 'Police',
#     'profileImageUrlLarge': '/api/users/tqdh-nm3t/profile_images/LARGE',
#     'profileImageUrlMedium': '/api/users/tqdh-nm3t/profile_images/THUMB',
#     'profileImageUrlSmall': '/api/users/tqdh-nm3t/profile_images/TINY',
#     'screenName': 'Police',
#     'type': 'interactive',
#     'userSegment': 'site_member',
#     'flags': ['acceptedEula']},
#    'query': {'orderBys': [{'ascending': False,
#       'expression': {'columnId': 465602715, 'type': 'column'}}]},
#    'rights': ['read'],
#    'tableAuthor': {'id': 'tqdh-nm3t',
#     'displayName': 'Police',
#     'profileImageUrlLarge': '/api/users/tqdh-nm3t/profile_images/LARGE',
#     'profileImageUrlMedium': '/api/users/tqdh-nm3t/profile_images/THUMB',
#     'profileImageUrlSmall': '/api/users/tqdh-nm3t/profile_images/TINY',
#     'screenName': 'Police',
#     'type': 'interactive',
#     'userSegment': 'site_member',
#     'flags': ['acceptedEula']},
#    'tags': ['enforcement',
#     'stop data',
#     'police',
#     'traffic',
#     'pedestrian',
#     'bicycle',
#     'detention',
#     'search'],
#    'flags': ['default', 'restorable', 'restorePossibleForType']}},
#  'data': [['row-2j6s.qe6z_jtkn',
#    '00000000-0000-0000-D599-E1C6017B6966',
#    0,
#    1589533219,
#    None,
#    1589533219,
#    None,
#    '{ }',
#    '2017-05-02T20:50:29',
#    '2017-00024695',
#    '1275 WALNUT ST',
#    'BERKELEY',
#    '37.88452086',
#    '-122.268652364',
#    '1194',
#    'White',
#    'Female',
#    '30-39',
#    'Investigation',
#    'Warning',
#    'No Search'],
#   ['row-79rz~ucps-35r6',
#    '00000000-0000-0000-B83C-7A2ADDC55727',
#    0,
#    1598605226,
#    None,
#    1598605226,
#    None,
#    '{ }',
#    '2018-02-20T18:42:04',
#    '2018-00010451',
#    '2176 KITTREDGE ST',
#    'BERKELEY',
#    '37.868233788',
#    '-122.266394615',
#    '1194',
#    'White',
#    'Male',
#    '>40',
#    'Investigation',
#    'Other',
#    'No Search'],
#   ['row-tmr9_n9ye.6bzh',
#    '00000000-0000-0000-3120-DC62279E5799',
#    0,
#    1598605226,
#    None,
#    1598605226,
#    None,
#    '{ }',
#    '2020-03-04T16:18:11',
#    '2020-00012764',
#    '1414 UNIVERSITY AVE',
#    'BERKELEY',
#    '37.869690714',
#    '-122.283865643',
#    'T',
#    'Black',
#    'Female',
#    '>40',
#    'Traffic',
#    'Citation',
#    'No Search'],
#   ['row-cjve_43yp_s8ec',
#    '00000000-0000-0000-4EEF-F940D151C603',
#    0,
#    1598605226,
#    None,
#    1598605226,
#    None,
#    '{ }',
#    '2018-12-04T15:11:14',
#    '2018-00067166',
#    '2300 SHATTUCK AVE',
#    'BERKELEY',
#    '37.867138358',
#    '-122.268229602',
#    '1196',
#    'Hispanic',
#    'Male',
#    '30-39',
#    'Traffic',
#    'Warning',
#    'No Search'],
#   ['row-wxqp_6mgh-v4r5',
#    '00000000-0000-0000-8B94-7D86EB47C51D',
#    0,
#    1589533219,
#    None,
#    1589533219,
#    None,
#    '{ }',
#    '2020-05-13T09:37:53',
#    '2020-00023435',
#    'SHATTUCK AVE / CHANNING WAY',
#    'BERKELEY',
#    '37.865779797',
#    '-122.267576002',
#    '1194',
#    'Black',
#    'Male',
#    '>40',
#    'Traffic',
#    'Citation',
#    'No Search'],
#   ['row-mf49~8gwk.k6g5',
#    '00000000-0000-0000-43A3-D477F3C07872',
#    0,
#    1598605226,
#    None,
#    1598605226,
#    None,
#    '{ }',
#    '2019-04-19T04:53:10',
#    '2019-00020838',
#    '3400 ADELINE ST',
#    'BERKELEY',
#    '37.846549841',
#    '-122.273012707',
#    '1196',
#    'Other',
#    'Male',
#    '18-29',
#    'Investigation',
#    'Warning',
#    'No Search'],
#   ['row-zks9-32fu.such',
#    '00000000-0000-0000-0073-AF5810C4FB2A',
#    0,
#    1598605226,
#    None,
#    1598605226,
#    None,
#    '{ }',
#    '2016-11-20T04:28:07',
#    '2016-00068586',
#    '1250 UNIVERSITY AVE',
#    'BERKELEY',
#    '37.869522906',
#    '-122.287045202',
#    '1196',
#    'Black',
#    'Male',
#    '>40',
#    'Investigation',
#    'Warning',
#    'No Search'],
#   ['row-5rst-vhd2-pwxf',
#    '00000000-0000-0000-1169-8943ED935A5C',
#    0,
#    1598605226,
#    None,
#    1598605226,
#    None,
#    '{ }',
#    '2020-01-26T23:35:54',
#    '2020-00004974',
#    '735 ASHBY AVE',
#    'BERKELEY',
#    '37.850242359',
#    '-122.294539787',
#    'T',
#    'Other',
#    'Female',
#    '>40',
#    'Traffic',
#    'Warning',
#    'No Search'],
#   ['row-44ny.assv-86xh',
#    '00000000-0000-0000-EEBF-C9FBD906B2FF',
#    0,
#    1598605226,
#    None,
#    1598605226,
#    None,
#    '{ }',
#    '2016-12-19T01:40:47',
#    '2016-00074453',
#    '2887 COLLEGE AVE',
#    'BERKELEY',
#    '37.858828873',
#    '-122.252913485',
#    '1194',
#    'White',
#    'Male',
#    '30-39',
#    'Investigation',
#    'Warning',
#    'No Search'],
#   ['row-cza5_4r84.ajdc',
#    '00000000-0000-0000-1729-EE9C56DE857D',
#    0,
#    1598605226,
#    None,
#    1598605226,
#    None,
#    '{ }',
#    '2017-04-15T22:30:50',
#    '2017-00021046',
#    'SACRAMENTO ST / HEARST AVE',
#    'BERKELEY',
#    '37.87214977',
#    '-122.282132237',
#    'T',
#    'Asian',
#    'Male',
#    '18-29',
#    'Traffic',
#    'Citation',
#    'No Search'],
#   ['row-d6py.pz96_fmie',
#    '00000000-0000-0000-AA3B-629A31DFBBA3',
#    0,
#    1598605226,
#    None,
#    1598605226,
#    None,
#    '{ }',
#    '2015-05-20T16:14:39',
#    '2015-00029190',
#    '2300 SHATTUCK AVE',
#    'BERKELEY',
#    '37.867138358',
#    '-122.268229602',
#    '1194',
#    'White',
#    'Male',
#    '18-29',
#    'Reas. Susp.',
#    'Warning',
#    'No Search'],
#   ['row-2yqq.nzuh~ifhs',
#    '00000000-0000-0000-D41E-7F2437B6D966',
#    0,
#    1598605226,
#    None,
#    1598605226,
#    None,
#    '{ }',
#    '2018-02-22T00:58:55',
#    '2018-00010752',
#    '2176 KITTREDGE ST',
#    'BERKELEY',
#    '37.868233788',
#    '-122.266394615',
#    'T',
#    'Hispanic',
#    'Female',
#    '30-39',
#    'Traffic',
#    'Warning',
#    'No Search'],
#   ['row-95yb_d3qx~vcuv',
#    '00000000-0000-0000-678F-3D0C673CC99E',
#    0,
#    1598605226,
#    None,
#    1598605226,
#    None,
#    '{ }',
#    '2016-08-06T22:03:41',
#    '2016-00046281',
#    '2887 COLLEGE AVE',
#    'BERKELEY',
#    '37.858828873',
#    '-122.252913485',
#    '1194',
#    'White',
#    'Male',
#    '>40',
#    'Investigation',
#    'Warning',
#    'No Search'],
#   ['row-x7kv~4czz.fkbb',
#    '00000000-0000-0000-211A-A6CC0F3D962A',
#    0,
#    1598605226,
#    None,
#    1598605226,
#    None,
#    '{ }',
#    '2020-02-22T03:50:01',
#    '2020-00010500',
#    '2887 COLLEGE AVE',
#    'BERKELEY',
#    '37.858828873',
#    '-122.252913485',
#    '1194',
#    'Other',
#    'Male',
#    '30-39',
#    'Investigation',
#    'Other',
#    'No Search'],
#   ['row-fnsd.s2ze-nfia',
#    '00000000-0000-0000-C998-ACF8DDF9F7EF',
#    0,
#    1598605226,
#    None,
#    1598605226,
#    None,
#    '{ }',
#    '2015-03-26T03:25:11',
#    '2015-00017523',
#    '3100 ADELINE ST',
#    'BERKELEY',
#    '37.852816873',
#    '-122.269302236',
#    '1194',
#    'Black',
#    'Male',
#    '30-39',
#    'Traffic',
#    'Warning',
#    'Search'],
#   ['row-nuu5_468n~9tuw',
#    '00000000-0000-0000-FEE9-230D2C25A302',
#    0,
#    1598605226,
#    None,
#    1598605226,
#    None,
#    '{ }',
#    '2016-01-03T01:06:56',
#    '2016-00000424',
#    '2176 KITTREDGE ST',
#    'BERKELEY',
#    '37.868233788',
#    '-122.266394615',
#    '1196',
#    'White',
#    'Male',
#    '>40',
#    'Traffic',
#    'Warning',
#    'No Search'],
#   ['row-9ps8-9jq2_xcmj',
#    '00000000-0000-0000-AEC8-0087973B5390',
#    0,
#    1598605226,
#    None,
#    1598605226,
#    None,
#    '{ }',
#    '2015-02-07T23:12:02',
#    '2015-00007800',
#    'DERBY ST / COLLEGE AVE',
#    'BERKELEY',
#    '37.862110702',
#    '-122.253539996',
#    '1194',
#    'Black',
#    'Female',
#    '18-29',
#    'Reas. Susp.',
#    'Citation',
#    'No Search'],
#   ['row-ed69-tr46-xwky',
#    '00000000-0000-0000-02E9-B2BE77DCF52E',
#    0,
#    1598605226,
#    None,
#    1598605226,
#    None,
#    '{ }',
#    '2016-04-03T20:45:26',
#    '2016-00019302',
#    '1284 SAN PABLO AVE',
#    'BERKELEY',
#    '37.88071829',
#    '-122.296279015',
#    '1194',
#    'White',
#    'Male',
#    '30-39',
#    'Reas. Susp.',
#    'Warning',
#    'No Search'],
#   ['row-7eik~wqiv.3xgs',
#    '00000000-0000-0000-4C7F-898C4A1A0406',
#    0,
#    1589533219,
#    None,
#    1589533219,
#    None,
#    '{ }',
#    '2017-04-15T00:55:42',
#    '2017-00020860',
#    'MILVIA ST / RUSSELL ST',
#    'BERKELEY',
#    '37.856420484',
#    '-122.269019382',
#    'T',
#    'Black',
#    'Female',
#    '30-39',
#    'Traffic',
#    'Warning',
#    'No Search'],
#   ['row-636p-g4cw~53q4',
#    '00000000-0000-0000-063B-25280E76DD98',
#    0,
#    1598605226,
#    None,
#    1598605226,
#    None,
#    '{ }',
#    '2016-01-01T01:32:25',
#    '2016-00000015',
#    'COLLEGE AVE / WEBSTER ST',
#    'BERKELEY',
#    '37.856080724',
#    '-122.252947114',
#    'T',
#    'Asian',
#    'Female',
#    '30-39',
#    'Traffic',
#    'Warning',
#    'No Search'],
#   ['row-6uh2~rxn3~xnhi',
#    '00000000-0000-0000-C3E5-9323C49E17CC',
#    0,
#    1598605226,
#    None,
#    1598605226,
#    None,
#    '{ }',
#    '2017-10-13T21:11:57',
#    '2017-00062089',
#    'SACRAMENTO ST / HEARST AVE',
#    'BERKELEY',
#    '37.87214977',
#    '-122.282132237',
#    'T',
#    'White',
#    'Male',
#    '30-39',
#    'Traffic',
#    'Warning',
#    'No Search'],
#   ['row-wes3_dtqc~e3js',
#    '00000000-0000-0000-6216-0629D9AB5FE6',
#    0,
#    1589533219,
#    None,
#    1589533219,
#    None,
#    '{ }',
#    '2020-05-13T21:55:54',
#    '2020-00023534',
#    '2ND ST / HARRISON ST',
#    'BERKELEY',
#    '37.880248146',
#    '-122.306339261',
#    '1194',
#    'White',
#    'Male',
#    '30-39',
#    'Investigation',
#    'Warning',
#    'No Search'],
#   ['row-qrhx.evwp.8apt',
#    '00000000-0000-0000-38C5-89A86D484608',
#    0,
#    1598605226,
#    None,
#    1598605226,
#    None,
#    '{ }',
#    '2015-05-14T10:37:29',
#    '2015-00027878',
#    '1284 SAN PABLO AVE',
#    'BERKELEY',
#    '37.88071829',
#    '-122.296279015',
#    '1194',
#    'White',
#    'Female',
#    '30-39',
#    'Reas. Susp.',
#    'Citation',
#    'No Search'],
#   ['row-ewjj_pghg-2yva',
#    '00000000-0000-0000-0C4D-9C9099E67430',
#    0,
#    1598605226,
#    None,
#    1598605226,
#    None,
#    '{ }',
#    '2017-11-06T01:39:26',
#    '2017-00067544',
#    '601 CEDAR ST',
#    'BERKELEY',
#    '37.873533173',
#    '-122.304755865',
#    '1196',
#    'White',
#    'Male',
#    '30-39',
#    'Investigation',
#    'Other',
#    'Search'],
#   ['row-jptg-rhsb.gy7r',
#    '00000000-0000-0000-1221-CA530B69B069',
#    0,
#    1598605226,
#    None,
#    1598605226,
#    None,
#    '{ }',
#    '2018-08-11T22:55:34',
#    '2018-00045230',
#    '1 SPINNAKER WAY',
#    'BERKELEY',
#    '37.869039977',
#    '-122.314673204',
#    '1196',
#    'White',
#    'Male',
#    '>40',
#    'Investigation',
#    'Warning',
#    'No Search'],
#   ['row-3man-yvty~u755',
#    '00000000-0000-0000-085E-73AD5C7D8410',
#    0,
#    1598605226,
#    None,
#    1598605226,
#    None,
#    '{ }',
#    '2015-04-08T13:42:39',
#    '2015-00020307',
#    '2201 SHATTUCK AVE',
#    'BERKELEY',
#    '37.869197273',
#    '-122.267440424',
#    '1194',
#    'White',
#    'Female',
#    '30-39',
#    'Reas. Susp.',
#    'Citation',
#    'No Search'],
#   ['row-knsr_f9q4.izzn',
#    '00000000-0000-0000-5B0A-E03867651243',
#    0,
#    1589533219,
#    None,
#    1589533219,
#    None,
#    '{ }',
#    '2017-05-02T20:50:29',
#    '2017-00024695',
#    '1275 WALNUT ST',
#    'BERKELEY',
#    '37.88452086',
#    '-122.268652364',
#    '1194',
#    'Black',
#    'Male',
#    '>40',
#    'Investigation',
#    'Warning',
#    'No Search'],
#   ['row-25jw~eacc.8ve5',
#    '00000000-0000-0000-1A0A-EC35CC290F61',
#    0,
#    1598605226,
#    None,
#    1598605226,
#    None,
#    '{ }',
#    '2015-04-05T09:46:54',
#    '2015-00019738',
#    '1250 UNIVERSITY AVE',
#    'BERKELEY',
#    '37.869522906',
#    '-122.287045202',
#    'T',
#    'White',
#    'Male',
#    '30-39',
#    'Traffic',
#    'Citation',
#    'No Search'],
#   ['row-6qx6.w4td~mfkq',
#    '00000000-0000-0000-FDC0-5E3785222440',
#    0,
#    1589533219,
#    None,
#    1589533219,
#    None,
#    '{ }',
#    '2017-10-28T23:53:57',
#    '2017-00065780',
#    'MILVIA ST / RUSSELL ST',
#    'BERKELEY',
#    '37.856420484',
#    '-122.269019382',
#    'T',
#    'White',
#    'Female',
#    '18-29',
#    'Traffic',
#    'Arrest',
#    'Search'],
#   ['row-hic4~9vnh.2tz7',
#    '00000000-0000-0000-CD1B-EF62CD842D8C',
#    0,
#    1598605226,
#    None,
#    1598605226,
#    None,
#    '{ }',
#    '2018-12-30T01:03:32',
#    '2018-00071731',
#    '1250 UNIVERSITY AVE',
#    'BERKELEY',
#    '37.869522906',
#    '-122.287045202',
#    '1196',
#    'Black',
#    'Male',
#    '>40',
#    'Investigation',
#    'Warning',
#    'Search'],
#   ['row-rvt6_24q3~u9ck',
#    '00000000-0000-0000-BC0B-9C45FB7FC330',
#    0,
#    1598605226,
#    None,
#    1598605226,
#    None,
#    '{ }',
#    '2016-05-24T13:09:30',
#    '2016-00030490',
#    '1625 RUSSELL ST',
#    'BERKELEY',
#    '37.855644914',
#    '-122.275777117',
#    'T',
#    'Black',
#    'Female',
#    '30-39',
#    'Traffic',
#    'Warning',
#    'No Search'],
#   ['row-42kd~x496-9iue',
#    '00000000-0000-0000-4B47-C3097C0DEF17',
#    0,
#    1598605226,
#    None,
#    1598605226,
#    None,
#    '{ }',
#    '2015-09-12T22:03:51',
#    '2015-00053948',
#    'PIEDMONT AVE / BANCROFT WAY',
#    'BERKELEY',
#    '37.869594957',
#    '-122.252292815',
#    'T',
#    'Asian',
#    'Male',
#    '18-29',
#    'Traffic',
#    'Citation',
#    'No Search'],
#   ['row-qdmj-jrp4~fvpk',
#    '00000000-0000-0000-0898-28D8B2759734',
#    0,
#    1589533219,
#    None,
#    1589533219,
#    None,
#    '{ }',
#    '2017-04-29T21:51:26',
#    '2017-00023979',
#    'MILVIA ST / RUSSELL ST',
#    'BERKELEY',
#    '37.856420484',
#    '-122.269019382',
#    'T',
#    'Hispanic',
#    'Female',
#    '>40',
#    'Traffic',
#    'Warning',
#    'Search'],
#   ['row-g9az~yjcg-hhth',
#    '00000000-0000-0000-7802-4EC43995F180',
#    0,
#    1598605226,
#    None,
#    1598605226,
#    None,
#    '{ }',
#    '2018-03-04T19:02:25',
#    '2018-00013042',
#    '1120 2ND ST',
#    'BERKELEY',
#    '37.881273721',
#    '-122.307263649',
#    '1196',
#    'White',
#    'Female',
#    '30-39',
#    'Investigation',
#    'Arrest',
#    'Search'],
#   ['row-bnep~mvjq.brwf',
#    '00000000-0000-0000-B4E0-05E359EBF272',
#    0,
#    1598605226,
#    None,
#    1598605226,
#    None,
#    '{ }',
#    '2017-11-14T09:08:42',
#    '2017-00069370',
#    'FULTON ST / DURANT AVE',
#    'BERKELEY',
#    '37.866930367',
#    '-122.265808619',
#    'T',
#    'Black',
#    'Female',
#    '30-39',
#    'Traffic',
#    'Warning',
#    'No Search'],
#   ['row-xd3c.eppc~x3rc',
#    '00000000-0000-0000-8EF4-DE922D13F2BA',
#    0,
#    1598605226,
#    None,
#    1598605226,
#    None,
#    '{ }',
#    '2019-04-10T16:09:14',
#    '2019-00019177',
#    '735 ASHBY AVE',
#    'BERKELEY',
#    '37.850242359',
#    '-122.294539787',
#    'T',
#    'White',
#    'Male',
#    '30-39',
#    'Traffic',
#    'Citation',
#    'No Search'],
#   ['row-n839-vqqm.ttpp',
#    '00000000-0000-0000-D9BA-A37BFD7E2469',
#    0,
#    1598605226,
#    None,
#    1598605226,
#    None,
#    '{ }',
#    '2019-08-30T12:57:34',
#    '2019-00048605',
#    '2996 TELEGRAPH AVE',
#    'BERKELEY',
#    '37.856404462',
#    '-122.260124918',
#    'T',
#    'Hispanic',
#    'Male',
#    '30-39',
#    'Traffic',
#    'Citation',
#    'No Search'],
#   ['row-9z7v~99y6~eyxs',
#    '00000000-0000-0000-0F54-0DE30B228F64',
#    0,
#    1589533219,
#    None,
#    1589533219,
#    None,
#    '{ }',
#    '2016-01-28T01:15:24',
#    '2016-00005401',
#    '1275 WALNUT ST',
#    'BERKELEY',
#    '37.88452086',
#    '-122.268652364',
#    '1194',
#    'White',
#    'Male',
#    '18-29',
#    'Investigation',
#    'Warning',
#    'No Search'],
#   ['row-cajm~ehd4.gtnt',
#    '00000000-0000-0000-8943-318213E5C132',
#    0,
#    1589533219,
#    None,
#    1589533219,
#    None,
#    '{ }',
#    '2016-01-28T01:15:24',
#    '2016-00005401',
#    '1275 WALNUT ST',
#    'BERKELEY',
#    '37.88452086',
#    '-122.268652364',
#    '1194',
#    'White',
#    'Male',
#    '30-39',
#    'Investigation',
#    'Warning',
#    'No Search'],
#   ['row-w3ek-4e84-mrwm',
#    '00000000-0000-0000-8B23-673505C7529E',
#    0,
#    1598605226,
#    None,
#    1598605226,
#    None,
#    '{ }',
#    '2020-08-26T11:08:17',
#    '2020-00039704',
#    '7TH ST / ASHBY AVE',
#    'BERKELEY',
#    '37.851008554',
#    '-122.291104028',
#    'T',
#    'White',
#    'Male',
#    '30-39',
#    'Traffic',
#    'Citation',
#    'No Search'],
#   ['row-dvxz-5gw6~zdda',
#    '00000000-0000-0000-CD49-902FC25FCBB7',
#    0,
#    1598605226,
#    None,
#    1598605226,
#    None,
#    '{ }',
#    '2017-09-09T03:07:44',
#    '2017-00054114',
#    '920 HEINZ AVE',
#    'BERKELEY',
#    '37.853329093',
#    '-122.290301603',
#    '1196',
#    'Other',
#    'Male',
#    '18-29',
#    'Investigation',
#    'Other',
#    'No Search'],
#   ['row-2n5u_pazi-c3i5',
#    '00000000-0000-0000-CC72-6CDC0CFE04B6',
#    0,
#    1598605226,
#    None,
#    1598605226,
#    None,
#    '{ }',
#    '2018-07-07T23:17:45',
#    '2018-00038308',
#    '735 ASHBY AVE',
#    'BERKELEY',
#    '37.850242359',
#    '-122.294539787',
#    'T',
#    'Black',
#    'Male',
#    '18-29',
#    'Traffic',
#    'Warning',
#    'No Search'],
#   ['row-ebn6~b2gh_i25a',
#    '00000000-0000-0000-1193-F9E6C4B29D69',
#    0,
#    1598605226,
#    None,
#    1598605226,
#    None,
#    '{ }',
#    '2017-07-24T00:47:24',
#    '2017-00042971',
#    '1250 UNIVERSITY AVE',
#    'BERKELEY',
#    '37.869522906',
#    '-122.287045202',
#    'T',
#    'Asian',
#    'Male',
#    '18-29',
#    'Traffic',
#    'Citation',
#    'No Search'],
#   ['row-77rt~upmw.zy4h',
#    '00000000-0000-0000-5C74-11BCCB23C804',
#    0,
#    1598605226,
#    None,
#    1598605226,
#    None,
#    '{ }',
#    '2015-04-08T12:05:47',
#    '2015-00020285',
#    'COLLEGE AVE / WEBSTER ST',
#    'BERKELEY',
#    '37.856080724',
#    '-122.252947114',
#    '1194',
#    'White',
#    'Male',
#    '18-29',
#    'Investigation',
#    'Warning',
#    'No Search'],
#   ['row-e2f9~6jg7_yfm9',
#    '00000000-0000-0000-CA71-EDC281D28E8B',
#    0,
#    1598605226,
#    None,
#    1598605226,
#    None,
#    '{ }',
#    '2020-08-26T10:50:28',
#    '2020-00039699',
#    '7TH ST / ASHBY AVE',
#    'BERKELEY',
#    '37.851008554',
#    '-122.291104028',
#    'T',
#    'White',
#    'Male',
#    '>40',
#    'Traffic',
#    'Citation',
#    'No Search'],
#   ['row-22eh_huau.azse',
#    '00000000-0000-0000-AC1A-DA60B6687BC8',
#    0,
#    1589533219,
#    None,
#    1589533219,
#    None,
#    '{ }',
#    '2015-09-28T16:10:53',
#    '2015-00057336',
#    '1275 WALNUT ST',
#    'BERKELEY',
#    '37.88452086',
#    '-122.268652364',
#    '1194',
#    'Black',
#    'Male',
#    '>40',
#    'Investigation',
#    'Arrest',
#    'Search'],
#   ['row-25r3-a59p-zx93',
#    '00000000-0000-0000-EB67-404E04515442',
#    0,
#    1598605226,
#    None,
#    1598605226,
#    None,
#    '{ }',
#    '2017-05-10T12:35:58',
#    '2017-00026397',
#    '2996 TELEGRAPH AVE',
#    'BERKELEY',
#    '37.856404462',
#    '-122.260124918',
#    'T',
#    'Other',
#    'Male',
#    '30-39',
#    'Traffic',
#    'Warning',
#    'No Search'],
#   ['row-e65p-8tus.asw4',
#    '00000000-0000-0000-8B48-994C41D3671D',
#    0,
#    1589533219,
#    None,
#    1589533219,
#    None,
#    '{ }',
#    '2017-04-29T21:51:26',
#    '2017-00023979',
#    'MILVIA ST / RUSSELL ST',
#    'BERKELEY',
#    '37.856420484',
#    '-122.269019382',
#    'T',
#    'Black',
#    'Female',
#    '18-29',
#    'Traffic',
#    'Warning',
#    'Search'],
#   ['row-mgwu_yj3g_icgu',
#    '00000000-0000-0000-4A52-7CA64230C4C4',
#    0,
#    1589533219,
#    None,
#    1589533219,
#    None,
#    '{ }',
#    '2017-04-29T21:51:26',
#    '2017-00023979',
#    'MILVIA ST / RUSSELL ST',
#    'BERKELEY',
#    '37.856420484',
#    '-122.269019382',
#    'T',
#    'Black',
#    'Male',
#    '18-29',
#    'Traffic',
#    'Warning',
#    'Search'],
#   ['row-7f9k~unqb-umcs',
#    '00000000-0000-0000-BAD8-FA557669E6E1',
#    0,
#    1598605226,
#    None,
#    1598605226,
#    None,
#    '{ }',
#    '2016-12-14T09:43:06',
#    '2016-00073346',
#    '735 ASHBY AVE',
#    'BERKELEY',
#    '37.850242359',
#    '-122.294539787',
#    'T',
#    'White',
#    'Female',
#    '30-39',
#    'Traffic',
#    'Citation',
#    'No Search'],
#   ['row-eh3f~6tcj.2pd8',
#    '00000000-0000-0000-CC59-FC14BA386647',
#    0,
#    1598605226,
#    None,
#    1598605226,
#    None,
#    '{ }',
#    '2016-05-15T15:10:05',
#    '2016-00028616',
#    '2539 TELEGRAPH AVE',
#    'BERKELEY',
#    '37.864244252',
#    '-122.258098577',
#    'T',
#    'Black',
#    'Female',
#    '18-29',
#    'Traffic',
#    'Citation',
#    'No Search'],
#   ['row-myvs.p67j_ur8r',
#    '00000000-0000-0000-CE86-DA45D3454013',
#    0,
#    1598605226,
#    None,
#    1598605226,
#    None,
#    '{ }',
#    '2016-08-10T03:40:03',
#    '2016-00046924',
#    '1500 UNIVERSITY AVE',
#    'BERKELEY',
#    '37.870124792',
#    '-122.28156683',
#    'T',
#    'White',
#    'Male',
#    '>40',
#    'Traffic',
#    'Warning',
#    'No Search'],
#   ['row-vhfv_a2wd_5gep',
#    '00000000-0000-0000-C9A7-B699F8E612DF',
#    0,
#    1598605226,
#    None,
#    1598605226,
#    None,
#    '{ }',
#    '2015-02-18T11:07:23',
#    '2015-00010085',
#    '1610 SAN PABLO AVE',
#    'BERKELEY',
#    '37.874480749',
#    '-122.2942758',
#    '1194',
#    'Black',
#    'Male',
#    '>40',
#    'Reas. Susp.',
#    'Citation',
#    'No Search'],
#   ['row-mrn8-3eux_tej3',
#    '00000000-0000-0000-8AF2-889A0DA92DF5',
#    0,
#    1598605226,
#    None,
#    1598605226,
#    None,
#    '{ }',
#    '2015-07-24T12:55:35',
#    '2015-00042883',
#    '735 ASHBY AVE',
#    'BERKELEY',
#    '37.850242359',
#    '-122.294539787',
#    'T',
#    'Black',
#    'Female',
#    '>40',
#    'Traffic',
#    'Citation',
#    'No Search'],
#   ['row-bnvc-pwx9-nyf5',
#    '00000000-0000-0000-3717-3A3A016E0DEC',
#    0,
#    1598605226,
#    None,
#    1598605226,
#    None,
#    '{ }',
#    '2015-11-09T23:51:46',
#    '2015-00066174',
#    '735 ASHBY AVE',
#    'BERKELEY',
#    '37.850242359',
#    '-122.294539787',
#    'T',
#    'Black',
#    'Male',
#    '18-29',
#    'Traffic',
#    'Warning',
#    'No Search'],
#   ['row-hqsj-8fpw-2v9b',
#    '00000000-0000-0000-9156-473923F1CD48',
#    0,
#    1598605226,
#    None,
#    1598605226,
#    None,
#    '{ }',
#    '2016-12-02T18:47:01',
#    '2016-00070985',
#    '1450 UNIVERSITY AVE',
#    'BERKELEY',
#    '37.869964072',
#    '-122.282932205',
#    'T',
#    'White',
#    'Female',
#    '>40',
#    'Traffic',
#    'Warning',
#    'No Search'],
#   ['row-jrj3-3w5x~m4nb',
#    '00000000-0000-0000-3B54-FC93BB3744C9',
#    0,
#    1598605226,
#    None,
#    1598605226,
#    None,
#    '{ }',
#    '2017-08-03T07:56:00',
#    '2017-00045121',
#    '3100 ADELINE ST',
#    'BERKELEY',
#    '37.852816873',
#    '-122.269302236',
#    'T',
#    'White',
#    'Female',
#    '18-29',
#    'Traffic',
#    'Citation',
#    'No Search'],
#   ['row-8mni-ruhy.qbn6',
#    '00000000-0000-0000-B8DE-8AD0A7D725AF',
#    0,
#    1598605226,
#    None,
#    1598605226,
#    None,
#    '{ }',
#    '2017-12-18T12:57:35',
#    '2017-00076634',
#    '2020 OREGON ST',
#    'BERKELEY',
#    '37.857010238',
#    '-122.267254672',
#    '1196',
#    'Black',
#    'Male',
#    '30-39',
#    'Investigation',
#    'Warning',
#    'No Search'],
#   ['row-n2aw.qzdw_3mpw',
#    '00000000-0000-0000-40A2-46FF5B7633D7',
#    0,
#    1598605226,
#    None,
#    1598605226,
#    None,
#    '{ }',
#    '2017-05-18T23:57:50',
#    '2017-00028262',
#    'COLLEGE AVE / WEBSTER ST',
#    'BERKELEY',
#    '37.856080724',
#    '-122.252947114',
#    'T',
#    'Asian',
#    'Female',
#    '30-39',
#    'Traffic',
#    'Warning',
#    'No Search'],
#   ['row-k5cs~f5s4-pbe7',
#    '00000000-0000-0000-3DAA-43771318158D',
#    0,
#    1598605226,
#    None,
#    1598605226,
#    None,
#    '{ }',
#    '2015-10-23T00:29:40',
#    '2015-00062466',
#    '2176 KITTREDGE ST',
#    'BERKELEY',
#    '37.868233788',
#    '-122.266394615',
#    '1194',
#    'White',
#    'Male',
#    '18-29',
#    'Investigation',
#    'Arrest',
#    'Search'],
#   ['row-d33e_tsdz_usa5',
#    '00000000-0000-0000-4D8E-3CFBDE8029BC',
#    0,
#    1598605226,
#    None,
#    1598605226,
#    None,
#    '{ }',
#    '2016-11-29T22:34:56',
#    '2016-00070376',
#    '2176 KITTREDGE ST',
#    'BERKELEY',
#    '37.868233788',
#    '-122.266394615',
#    '1196',
#    'Black',
#    'Male',
#    '18-29',
#    'Reas. Susp.',
#    'Warning',
#    'No Search'],
#   ['row-bpwx-i47e-ebmn',
#    '00000000-0000-0000-424D-B05D300AEE87',
#    0,
#    1598605226,
#    None,
#    1598605226,
#    None,
#    '{ }',
#    '2019-01-01T22:28:03',
#    '2019-00000125',
#    '735 ASHBY AVE',
#    'BERKELEY',
#    '37.850242359',
#    '-122.294539787',
#    'T',
#    'Black',
#    'Male',
#    '30-39',
#    'Traffic',
#    'Warning',
#    'No Search'],
#   ['row-8ekb_pwc8.euv5',
#    '00000000-0000-0000-5E01-B8968F53AE49',
#    0,
#    1598605226,
#    None,
#    1598605226,
#    None,
#    '{ }',
#    '2019-12-21T08:48:29',
#    '2019-00072222',
#    '1050 GILMAN ST',
#    'BERKELEY',
#    '37.879199046',
#    '-122.296286004',
#    'T',
#    'Black',
#    'Female',
#    '30-39',
#    'Traffic',
#    'Warning',
#    'No Search'],
#   ['row-acw3.t6xg-wrnp',
#    '00000000-0000-0000-E15D-4FA625842E37',
#    0,
#    1598605226,
#    None,
#    1598605226,
#    None,
#    '{ }',
#    '2016-10-05T23:36:15',
#    '2016-00059313',
#    '2176 KITTREDGE ST',
#    'BERKELEY',
#    '37.868233788',
#    '-122.266394615',
#    '1194',
#    'Black',
#    'Male',
#    '>40',
#    'Prob./Parole',
#    'Warning',
#    'Search'],
#   ['row-ir4h-ce2w-u5ci',
#    '00000000-0000-0000-3B9B-B071B351FF16',
#    0,
#    1598605226,
#    None,
#    1598605226,
#    None,
#    '{ }',
#    '2017-01-26T14:07:52',
#    '2017-00004813',
#    'DERBY ST / COLLEGE AVE',
#    'BERKELEY',
#    '37.862110702',
#    '-122.253539996',
#    'T',
#    'White',
#    'Male',
#    '18-29',
#    'Traffic',
#    'Warning',
#    'No Search'],
#   ['row-2i4t.7sss-wsfj',
#    '00000000-0000-0000-DFBB-B7C62FEE7F51',
#    0,
#    1598605226,
#    None,
#    1598605226,
#    None,
#    '{ }',
#    '2016-10-12T23:10:29',
#    '2016-00060741',
#    'COLLEGE AVE / WEBSTER ST',
#    'BERKELEY',
#    '37.856080724',
#    '-122.252947114',
#    'T',
#    'Black',
#    'Female',
#    '18-29',
#    'Traffic',
#    'Warning',
#    'Search'],
#   ['row-v46s_hawh.g85e',
#    '00000000-0000-0000-6CC9-CC32D5420987',
#    0,
#    1598605226,
#    None,
#    1598605226,
#    None,
#    '{ }',
#    '2020-02-21T04:43:58',
#    '2020-00010224',
#    '735 ASHBY AVE',
#    'BERKELEY',
#    '37.850242359',
#    '-122.294539787',
#    'T',
#    'Black',
#    'Male',
#    '>40',
#    'Traffic',
#    'Warning',
#    'No Search'],
#   ['row-8jp8-gnkf_dpkx',
#    '00000000-0000-0000-AEF4-82F5FABA831E',
#    0,
#    1598605226,
#    None,
#    1598605226,
#    None,
#    '{ }',
#    '2015-11-08T21:41:25',
#    '2015-00065958',
#    '2176 KITTREDGE ST',
#    'BERKELEY',
#    '37.868233788',
#    '-122.266394615',
#    '1196',
#    'Other',
#    'Male',
#    '>40',
#    'Traffic',
#    'Warning',
#    'Search'],
#   ['row-hscj_f93f~e6t7',
#    '00000000-0000-0000-CE56-E61CF8F24EB8',
#    0,
#    1598605226,
#    None,
#    1598605226,
#    None,
#    '{ }',
#    '2019-05-27T04:58:54',
#    '2019-00028785',
#    '2996 SHATTUCK AVE',
#    'BERKELEY',
#    '37.855453608',
#    '-122.26686092',
#    'T',
#    'Black',
#    'Female',
#    '18-29',
#    'Traffic',
#    'Warning',
#    'No Search'],
#   ['row-5ap7-zxms.bcmr',
#    '00000000-0000-0000-B224-27C5DCBF6417',
#    0,
#    1598605226,
#    None,
#    1598605226,
#    None,
#    '{ }',
#    '2019-12-01T23:14:21',
#    '2019-00068162',
#    '2164 CENTER ST',
#    'BERKELEY',
#    '37.870320117',
#    '-122.266141153',
#    '1194',
#    'Other',
#    'Male',
#    '30-39',
#    'Investigation',
#    'Warning',
#    'Search'],
#   ['row-464b-mxex~u8ii',
#    '00000000-0000-0000-8063-6B1B129D7D11',
#    0,
#    1598605226,
#    None,
#    1598605226,
#    None,
#    '{ }',
#    '2016-06-26T23:23:05',
#    '2016-00037902',
#    '2176 KITTREDGE ST',
#    'BERKELEY',
#    '37.868233788',
#    '-122.266394615',
#    '1194',
#    'White',
#    'Male',
#    '18-29',
#    'Investigation',
#    'Warning',
#    'No Search'],
#   ['row-tb7s~4d8r~bzcf',
#    '00000000-0000-0000-311F-619E03B63490',
#    0,
#    1598605226,
#    None,
#    1598605226,
#    None,
#    '{ }',
#    '2019-03-14T18:02:22',
#    '2019-00013663',
#    '735 ASHBY AVE',
#    'BERKELEY',
#    '37.850242359',
#    '-122.294539787',
#    'T',
#    'Hispanic',
#    'Female',
#    '18-29',
#    'Traffic',
#    'Citation',
#    'No Search'],
#   ['row-2hds.4v4e~vmxp',
#    '00000000-0000-0000-95FE-759892DA730C',
#    0,
#    1598605226,
#    None,
#    1598605226,
#    None,
#    '{ }',
#    '2015-10-12T17:11:36',
#    '2015-00060291',
#    '1536 SHATTUCK AVE',
#    'BERKELEY',
#    '37.879416641',
#    '-122.269868952',
#    '1194',
#    'White',
#    'Male',
#    '>40',
#    'Investigation',
#    'Warning',
#    'No Search'],
#   ['row-854y_8r8j~qx7x',
#    '00000000-0000-0000-CAEF-C6BB56BD47CD',
#    0,
#    1598605226,
#    None,
#    1598605226,
#    None,
#    '{ }',
#    '2016-07-07T12:07:54',
#    '2016-00040066',
#    '1250 UNIVERSITY AVE',
#    'BERKELEY',
#    '37.869522906',
#    '-122.287045202',
#    '1194',
#    'Black',
#    'Male',
#    '>40',
#    'Investigation',
#    'Warning',
#    'No Search'],
#   ['row-98zf.9rtk.544k',
#    '00000000-0000-0000-1ED1-A05D642CC12C',
#    0,
#    1598605226,
#    None,
#    1598605226,
#    None,
#    '{ }',
#    '2019-08-20T07:24:36',
#    '2019-00046191',
#    '3100 ADELINE ST',
#    'BERKELEY',
#    '37.852816873',
#    '-122.269302236',
#    'T',
#    'Asian',
#    'Male',
#    '18-29',
#    'Traffic',
#    'Citation',
#    'No Search'],
#   ['row-qxbb~sz92-rdmp',
#    '00000000-0000-0000-78D2-5A99AB50234A',
#    0,
#    1598605226,
#    None,
#    1598605226,
#    None,
#    '{ }',
#    '2018-11-11T21:52:57',
#    '2018-00063297',
#    '2176 KITTREDGE ST',
#    'BERKELEY',
#    '37.868233788',
#    '-122.266394615',
#    '1196',
#    'Black',
#    'Male',
#    '<18',
#    'Reas. Susp.',
#    'Warning',
#    'Search'],
#   ['row-iuu5_vwyc.s2r3',
#    '00000000-0000-0000-D5F2-F4221BBF0A8B',
#    0,
#    1598605226,
#    None,
#    1598605226,
#    None,
#    '{ }',
#    '2015-11-16T15:00:00',
#    '2015-00067394',
#    '2300 SHATTUCK AVE',
#    'BERKELEY',
#    '37.867138358',
#    '-122.268229602',
#    '1194',
#    'White',
#    'Female',
#    '<18',
#    'Reas. Susp.',
#    'Citation',
#    'No Search'],
#   ['row-9g9i-u8mb-75ee',
#    '00000000-0000-0000-EDDD-1C9989F01D5B',
#    0,
#    1598605226,
#    None,
#    1598605226,
#    None,
#    '{ }',
#    '2018-08-26T00:17:24',
#    '2018-00048049',
#    '1250 UNIVERSITY AVE',
#    'BERKELEY',
#    '37.869522906',
#    '-122.287045202',
#    '1194',
#    'White',
#    'Male',
#    '30-39',
#    'Prob./Parole',
#    'Other',
#    'No Search'],
#   ['row-4gne-9sm5~zt8z',
#    '00000000-0000-0000-A8B6-EE4283C49D9B',
#    0,
#    1598605226,
#    None,
#    1598605226,
#    None,
#    '{ }',
#    '2018-01-31T08:22:20',
#    '2018-00006182',
#    '3100 ADELINE ST',
#    'BERKELEY',
#    '37.852816873',
#    '-122.269302236',
#    'T',
#    'White',
#    'Male',
#    '>40',
#    'Traffic',
#    'Citation',
#    'No Search'],
#   ['row-3s9p~z7dc~93uw',
#    '00000000-0000-0000-04BD-EB5EC59F4BAE',
#    0,
#    1598605226,
#    None,
#    1598605226,
#    None,
#    '{ }',
#    '2016-11-26T21:31:11',
#    '2016-00069807',
#    'COLLEGE AVE / WEBSTER ST',
#    'BERKELEY',
#    '37.856080724',
#    '-122.252947114',
#    'T',
#    'White',
#    'Male',
#    '18-29',
#    'Traffic',
#    'Warning',
#    'No Search'],
#   ['row-xww4_txn8.y3qj',
#    '00000000-0000-0000-D662-F5B30D742487',
#    0,
#    1598605226,
#    None,
#    1598605226,
#    None,
#    '{ }',
#    '2015-02-16T21:54:03',
#    '2015-00009788',
#    'DURANT AVE / FULTON ST',
#    'BERKELEY',
#    '37.866930367',
#    '-122.265808619',
#    'T',
#    'Hispanic',
#    'Male',
#    '18-29',
#    'Traffic',
#    'Citation',
#    'Search'],
#   ['row-t6jx_b4sa~susg',
#    '00000000-0000-0000-EBE7-E169121DE759',
#    0,
#    1598605226,
#    None,
#    1598605226,
#    None,
#    '{ }',
#    '2020-08-26T11:05:58',
#    '2020-00039703',
#    'ASHBY AVE / 7TH ST',
#    'BERKELEY',
#    '37.851008554',
#    '-122.291104028',
#    'T',
#    'Black',
#    'Male',
#    '>40',
#    'Traffic',
#    'Citation',
#    'No Search'],
#   ['row-2uqs.h7ih~49kf',
#    '00000000-0000-0000-7919-93F07ED6F85A',
#    0,
#    1590138020,
#    None,
#    1590138020,
#    None,
#    '{ }',
#    '2020-05-15T14:16:47',
#    '2020-00023759',
#    'BLAKE ST / DANA ST',
#    'BERKELEY',
#    '37.863936238',
#    '-122.260531615',
#    '1194B',
#    'Black',
#    'Male',
#    '>40',
#    'Prob./Parole',
#    'Warning',
#    'Search'],
#   ['row-smk7-gq3c_xmh4',
#    '00000000-0000-0000-A9E4-7CB44AB1179D',
#    0,
#    1598605226,
#    None,
#    1598605226,
#    None,
#    '{ }',
#    '2018-03-16T16:47:50',
#    '2018-00015549',
#    '2310 8TH ST',
#    'BERKELEY',
#    '37.863462836',
#    '-122.294143449',
#    'T',
#    'Black',
#    'Female',
#    '30-39',
#    'Traffic',
#    'Citation',
#    'No Search'],
#   ['row-2hda_isfr~76v9',
#    '00000000-0000-0000-F9B5-91A62CFCEF3C',
#    0,
#    1598605226,
#    None,
#    1598605226,
#    None,
#    '{ }',
#    '2017-07-01T22:50:57',
#    '2017-00038090',
#    '1250 UNIVERSITY AVE',
#    'BERKELEY',
#    '37.869522906',
#    '-122.287045202',
#    'T',
#    'Hispanic',
#    'Male',
#    '<18',
#    'Traffic',
#    'Warning',
#    'No Search'],
#   ['row-ane3_m7j8_ithp',
#    '00000000-0000-0000-7E90-ED83A0CECD22',
#    0,
#    1598605226,
#    None,
#    1598605226,
#    None,
#    '{ }',
#    '2015-03-03T16:16:07',
#    '2015-00012820',
#    'DURANT AVE / FULTON ST',
#    'BERKELEY',
#    '37.866930367',
#    '-122.265808619',
#    'T',
#    'Other',
#    'Female',
#    '18-29',
#    'Traffic',
#    'Citation',
#    'No Search'],
#   ['row-8a9n-y7ab-7uup',
#    '00000000-0000-0000-2195-D82468BC13C5',
#    0,
#    1598605226,
#    None,
#    1598605226,
# ...
#    'No Search'],
#   ['row-vms9-wkku-tszc',
#    '00000000-0000-0000-3996-CF2467E3FC06',
#    0,
#    1591991808,
#    None,
#    1591991808,
#    None,
#    '{ }',
#    '2020-06-03T22:02:45',
#    '2020-00026985',
#    'ASHBY AVE / SACRAMENTO ST',
#    'BERKELEY',
#    '37.853281083',
#    '-122.279011568',
#    'T',
#    'Black',
#    'Female',
#    '18-29',
#    'Traffic',
#    'Warning',
#    'No Search'],
#   ['row-quv3.apxi.ca2s',
#    '00000000-0000-0000-6417-86FE2ABF3E84',
#    0,
#    1591991808,
#    None,
#    1591991808,
#    None,
#    '{ }',
#    '2020-06-05T04:25:56',
#    '2020-00027196',
#    'CENTER ST / SHATTUCK AVE',
#    'BERKELEY',
#    '37.870303732',
#    '-122.268035507',
#    'T',
#    'Hispanic',
#    'Male',
#    '30-39',
#    'Traffic',
#    'Warning',
#    'No Search'],
#   ['row-nsyx-zc5z_r67i',
#    '00000000-0000-0000-1293-E778C3AC3553',
#    0,
#    1591991808,
#    None,
#    1591991808,
#    None,
#    '{ }',
#    '2019-11-08T20:54:51',
#    '2019-00063685',
#    'CALIFORNIA ST / ASHBY AVE',
#    'BERKELEY',
#    '37.853550724',
#    '-122.276930825',
#    'T',
#    'Black',
#    'Male',
#    '18-29',
#    'Traffic',
#    'Warning',
#    'Search'],
#   ['row-9axa-7w3r~gkcy',
#    '00000000-0000-0000-829E-E042775D39C0',
#    0,
#    1591991808,
#    None,
#    1591991808,
#    None,
#    '{ }',
#    '2018-07-15T20:10:35',
#    '2018-00039845',
#    'CALIFORNIA ST / ASHBY AVE',
#    'BERKELEY',
#    '37.853550724',
#    '-122.276930825',
#    'T',
#    'Black',
#    'Male',
#    '18-29',
#    'Traffic',
#    'Warning',
#    'No Search'],
#   ['row-evdk-f8pr-edfx',
#    '00000000-0000-0000-D18A-2ABBF3110078',
#    0,
#    1591991808,
#    None,
#    1591991808,
#    None,
#    '{ }',
#    '2020-06-02T19:56:40',
#    '2020-00026717',
#    'CHANNING WAY / SAN PABLO AVE',
#    'BERKELEY',
#    '37.86285483',
#    '-122.290106377',
#    'T',
#    'Black',
#    'Female',
#    '18-29',
#    'Traffic',
#    'Warning',
#    'No Search'],
#   ['row-4zdn~r32e-9a83',
#    '00000000-0000-0000-8BA0-695211AAA95D',
#    0,
#    1591991808,
#    None,
#    1591991808,
#    None,
#    '{ }',
#    '2020-06-10T00:33:33',
#    '2020-00027909',
#    'COLLEGE AVE / DWIGHT WAY',
#    'BERKELEY',
#    '37.865720759',
#    '-122.253902515',
#    'T',
#    'Black',
#    'Male',
#    '30-39',
#    'Traffic',
#    'Warning',
#    'No Search'],
#   ['row-c2eb~trpp-nx2n',
#    '00000000-0000-0000-8D3B-C34B7AE5F9BC',
#    0,
#    1591991808,
#    None,
#    1591991808,
#    None,
#    '{ }',
#    '2016-09-19T23:33:09',
#    '2016-00055636',
#    'UNIVERSITY AVE / WEST ST',
#    'BERKELEY',
#    '37.869817619',
#    '-122.286547791',
#    'T',
#    'Black',
#    'Male',
#    '30-39',
#    'Traffic',
#    'Warning',
#    'Search'],
#   ['row-777f-jvqg~xa32',
#    '00000000-0000-0000-7523-6CE579CFD0A4',
#    0,
#    1591991808,
#    None,
#    1591991808,
#    None,
#    '{ }',
#    '2020-06-03T22:21:04',
#    '2020-00026992',
#    'CARLETON ST / FULTON ST',
#    'BERKELEY',
#    '37.861566998',
#    '-122.264679694',
#    'T',
#    'White',
#    'Male',
#    '>40',
#    'Traffic',
#    'Warning',
#    'No Search'],
#   ['row-v8q2~z4ky~5gwf',
#    '00000000-0000-0000-071A-5943F45504D6',
#    0,
#    1591991808,
#    None,
#    1591991808,
#    None,
#    '{ }',
#    '2015-11-18T18:53:34',
#    '2015-00067871',
#    '7TH ST / DWIGHT WAY',
#    'BERKELEY',
#    '37.860196423',
#    '-122.294054192',
#    'T',
#    'White',
#    'Male',
#    '>40',
#    'Traffic',
#    'Warning',
#    'No Search'],
#   ['row-ngif-ikfu_iwm5',
#    '00000000-0000-0000-E4F0-EEE7C102538B',
#    0,
#    1591991808,
#    None,
#    1591991808,
#    None,
#    '{ }',
#    '2020-06-07T03:06:48',
#    '2020-00027497',
#    'PARK ST / OREGON ST',
#    'BERKELEY',
#    '37.855574396',
#    '-122.283033214',
#    'T',
#    'White',
#    'Female',
#    '30-39',
#    'Traffic',
#    'Warning',
#    'No Search'],
#   ['row-sw9r_psfs-ugyh',
#    '00000000-0000-0000-19DE-422D59BA8784',
#    0,
#    1591991808,
#    None,
#    1591991808,
#    None,
#    '{ }',
#    '2017-07-11T02:23:03',
#    '2017-00040078',
#    'UNIVERSITY AVE / WEST ST',
#    'BERKELEY',
#    '37.869817619',
#    '-122.286547791',
#    'T',
#    'Hispanic',
#    'Female',
#    '>40',
#    'Traffic',
#    'Warning',
#    'No Search'],
#   ['row-7mee.e6na.4rnt',
#    '00000000-0000-0000-F9BB-35A3B0DF290B',
#    0,
#    1591991808,
#    None,
#    1591991808,
#    None,
#    '{ }',
#    '2017-08-30T14:42:47',
#    '2017-00051587',
#    'HEARST AVE / 4TH ST',
#    'BERKELEY',
#    '37.868876205',
#    '-122.300284494',
#    'T',
#    'White',
#    'Male',
#    '>40',
#    'Traffic',
#    'Warning',
#    'No Search'],
#   ['row-get5~rvfv.zrid',
#    '00000000-0000-0000-C358-6457A6706770',
#    0,
#    1591991808,
#    None,
#    1591991808,
#    None,
#    '{ }',
#    '2017-05-13T02:16:16',
#    '2017-00026993',
#    '9TH ST / HEINZ AVE',
#    'BERKELEY',
#    '37.853935052',
#    '-122.289669456',
#    '1194',
#    'Other',
#    'Male',
#    '>40',
#    'Investigation',
#    'Warning',
#    'No Search'],
#   ['row-rt6m.nazx.vdce',
#    '00000000-0000-0000-8ECF-28F5D934C61F',
#    0,
#    1591991808,
#    None,
#    1591991808,
#    None,
#    '{ }',
#    '2020-06-02T21:59:50',
#    '2020-00026762',
#    'SHATTUCK AVE / ASHBY AVE',
#    'BERKELEY',
#    '37.855300551',
#    '-122.266493175',
#    'T',
#    'Asian',
#    'Male',
#    '18-29',
#    'Traffic',
#    'Warning',
#    'No Search'],
#   ['row-kghn~k437.nmxf',
#    '00000000-0000-0000-2B24-3E34DC270C58',
#    0,
#    1591991808,
#    None,
#    1591991808,
#    None,
#    '{ }',
#    '2020-06-06T18:46:14',
#    '2020-00027429',
#    'SACRAMENTO ST / TYLER ST',
#    'BERKELEY',
#    '37.852391498',
#    '-122.278804904',
#    'T',
#    'Hispanic',
#    'Male',
#    '18-29',
#    'Traffic',
#    'Warning',
#    'No Search'],
#   ['row-xwz4-egeb~fupr',
#    '00000000-0000-0000-3ADB-19148FD61D43',
#    0,
#    1591991808,
#    None,
#    1591991808,
#    None,
#    '{ }',
#    '2017-06-02T09:08:46',
#    '2017-00031420',
#    'HEARST AVE / 4TH ST',
#    'BERKELEY',
#    '37.868876205',
#    '-122.300284494',
#    'T',
#    'Black',
#    'Male',
#    '18-29',
#    'Traffic',
#    'Citation',
#    'No Search'],
#   ['row-hjua~jivf.z3kq',
#    '00000000-0000-0000-33E3-5D929B46398B',
#    0,
#    1591991808,
#    None,
#    1591991808,
#    None,
#    '{ }',
#    '2020-06-03T21:36:16',
#    '2020-00026978',
#    None,
#    'BERKELEY',
#    '37.876277692',
#    '-122.306321106',
#    'T',
#    'Black',
#    'Male',
#    '>40',
#    'Traffic',
#    'Warning',
#    'No Search'],
#   ['row-dzjc.ak3p~76et',
#    '00000000-0000-0000-7581-015B8B175FCF',
#    0,
#    1591991808,
#    None,
#    1591991808,
#    None,
#    '{ }',
#    '2020-06-12T01:28:41',
#    '2020-00028242',
#    'OXFORD ST / CENTER ST',
#    'BERKELEY',
#    '37.870584527',
#    '-122.265883486',
#    '1194',
#    'White',
#    'Male',
#    '30-39',
#    'Traffic',
#    'Warning',
#    'No Search'],
#   ['row-bwyr-6emm.q38b',
#    '00000000-0000-0000-898A-697F85F173DB',
#    0,
#    1591991808,
#    None,
#    1591991808,
#    None,
#    '{ }',
#    '2017-03-19T22:54:31',
#    '2017-00015433',
#    '7TH ST / DWIGHT WAY',
#    'BERKELEY',
#    '37.860196423',
#    '-122.294054192',
#    'T',
#    'White',
#    'Male',
#    '>40',
#    'Traffic',
#    'Warning',
#    'No Search'],
#   ['row-ipeh_twee-mvx3',
#    '00000000-0000-0000-AE20-490CA3BD5DA1',
#    0,
#    1591991808,
#    None,
#    1591991808,
#    None,
#    '{ }',
#    '2020-06-03T21:49:35',
#    '2020-00026982',
#    '7TH ST / CARLETON ST',
#    'BERKELEY',
#    '37.856944934',
#    '-122.293012467',
#    'T',
#    'White',
#    'Female',
#    '>40',
#    'Traffic',
#    'Warning',
#    'No Search'],
#   ['row-uyy7-kt5h.5wmf',
#    '00000000-0000-0000-FE3A-22F7104E0F9E',
#    0,
#    1591991808,
#    None,
#    1591991808,
#    None,
#    '{ }',
#    '2020-06-02T20:36:05',
#    '2020-00026729',
#    'CENTER ST / SHATTUCK AVE',
#    'BERKELEY',
#    '37.870303732',
#    '-122.268035507',
#    'T',
#    'Black',
#    'Female',
#    '18-29',
#    'Traffic',
#    'Citation',
#    'No Search'],
#   ['row-grsd~j55x.6v3z',
#    '00000000-0000-0000-539A-18EBE842E2E9',
#    0,
#    1598605226,
#    None,
#    1598605226,
#    None,
#    '{ }',
#    '2015-08-04T09:02:21',
#    '2015-00045199',
#    'SACRAMENTO ST / HEARST AVE',
#    'BERKELEY',
#    '37.87214977',
#    '-122.282132237',
#    'T',
#    'White',
#    'Female',
#    '>40',
#    'Traffic',
#    'Citation',
#    'No Search'],
#   ['row-5ha9.4zjz-ejqk',
#    '00000000-0000-0000-8C7C-DFAD91AE36AB',
#    0,
#    1598605226,
#    None,
#    1598605226,
#    None,
#    '{ }',
#    '2018-11-07T19:18:46',
#    '2018-00062621',
#    '2802 PARK ST',
#    'BERKELEY',
#    '37.85545827',
#    '-122.283044932',
#    'T',
#    'Black',
#    'Male',
#    '30-39',
#    'Traffic',
#    'Warning',
#    'No Search'],
#   ['row-tyj9.kfgp-rwfd',
#    '00000000-0000-0000-D7C2-7F7A89DDAE66',
#    0,
#    1598605226,
#    None,
#    1598605226,
#    None,
#    '{ }',
#    '2017-03-08T02:07:39',
#    '2017-00012914',
#    '1500 UNIVERSITY AVE',
#    'BERKELEY',
#    '37.870124792',
#    '-122.28156683',
#    '1194',
#    'White',
#    'Male',
#    '30-39',
#    'Investigation',
#    'Warning',
#    'Search'],
#   ['row-hwsh~e7pv-kaes',
#    '00000000-0000-0000-6398-58040986E3E7',
#    0,
#    1591991808,
#    None,
#    1591991808,
#    None,
#    '{ }',
#    '2019-06-10T15:03:23',
#    '2019-00031596',
#    '7TH ST / DWIGHT WAY',
#    'BERKELEY',
#    '37.860196423',
#    '-122.294054192',
#    'T',
#    'Black',
#    'Male',
#    '30-39',
#    'Traffic',
#    'Citation',
#    'No Search'],
#   ['row-w5fw~pai3~ertc',
#    '00000000-0000-0000-1DF1-4FA07ADA0457',
#    0,
#    1591991808,
#    None,
#    1591991808,
#    None,
#    '{ }',
#    '2020-06-01T22:36:52',
#    '2020-00026553',
#    '6TH ST / CHANNING WAY',
#    'BERKELEY',
#    '37.861743999',
#    '-122.295650698',
#    'T',
#    'Other',
#    'Female',
#    '>40',
#    'Traffic',
#    'Warning',
#    'No Search'],
#   ['row-cxkt-7zxd-zp9v',
#    '00000000-0000-0000-37EA-D573ED16AF8E',
#    0,
#    1591991808,
#    None,
#    1591991808,
#    None,
#    '{ }',
#    '2020-06-01T22:54:21',
#    '2020-00026560',
#    'SAN PABLO AVE / GILMAN ST',
#    'BERKELEY',
#    '37.880474184',
#    '-122.295799217',
#    'T',
#    'Hispanic',
#    'Male',
#    '18-29',
#    'Traffic',
#    'Warning',
#    'No Search'],
#   ['row-wpqh-rexm.ptzp',
#    '00000000-0000-0000-53E8-76BA714AF2DE',
#    0,
#    1598605226,
#    None,
#    1598605226,
#    None,
#    '{ }',
#    '2020-01-28T18:33:40',
#    '2020-00005367',
#    '2020 OREGON ST',
#    'BERKELEY',
#    '37.857010238',
#    '-122.267254672',
#    'T',
#    'White',
#    'Male',
#    '30-39',
#    'Traffic',
#    'Citation',
#    'No Search'],
#   ['row-z2cu_be6r-zqan',
#    '00000000-0000-0000-6C88-9830C34B6CD0',
#    0,
#    1591991808,
#    None,
#    1591991808,
#    None,
#    '{ }',
#    '2020-06-03T21:57:48',
#    '2020-00026984',
#    'UNIVERSITY AVE / 6TH ST',
#    'BERKELEY',
#    '37.867993895',
#    '-122.297664389',
#    'T',
#    'Asian',
#    'Male',
#    '30-39',
#    'Traffic',
#    'Citation',
#    'Search'],
#   ['row-33h7_4yi9~7tfg',
#    '00000000-0000-0000-8C09-5142758A314B',
#    0,
#    1591991808,
#    None,
#    1591991808,
#    None,
#    '{ }',
#    '2019-08-21T01:36:05',
#    '2019-00046426',
#    'HEARST AVE / 4TH ST',
#    'BERKELEY',
#    '37.868876205',
#    '-122.300284494',
#    'T',
#    'Hispanic',
#    'Male',
#    '30-39',
#    'Traffic',
#    'Warning',
#    'No Search'],
#   ['row-eqst~83yw.6pnk',
#    '00000000-0000-0000-79F7-BC0919CC0DCD',
#    0,
#    1591991808,
#    None,
#    1591991808,
#    None,
#    '{ }',
#    '2020-06-02T01:07:43',
#    '2020-00026602',
#    '4TH ST / VIRGINIA ST',
#    'BERKELEY',
#    '37.87188441',
#    '-122.301244582',
#    'T',
#    'Black',
#    'Male',
#    '30-39',
#    'Traffic',
#    'Warning',
#    'Search'],
#   ['row-8gjg.9fx2-he36',
#    '00000000-0000-0000-9074-CFFDBF7B7D37',
#    0,
#    1598605226,
#    None,
#    1598605226,
#    None,
#    '{ }',
#    '2017-08-29T12:07:02',
#    '2017-00051272',
#    '735 ASHBY AVE',
#    'BERKELEY',
#    '37.850242359',
#    '-122.294539787',
#    'T',
#    'Hispanic',
#    'Male',
#    '18-29',
#    'Traffic',
#    'Citation',
#    'No Search'],
#   ['row-26su_wwfc~q2tq',
#    '00000000-0000-0000-4737-6D7B0B45E1FF',
#    0,
#    1591991808,
#    None,
#    1591991808,
#    None,
#    '{ }',
#    '2020-06-10T21:59:15',
#    '2020-00028067',
#    'SAN PABLO AVE / BANCROFT WAY',
#    'BERKELEY',
#    '37.864616561',
#    '-122.290672073',
#    'T',
#    'Black',
#    'Female',
#    '>40',
#    'Traffic',
#    'Warning',
#    'No Search'],
#   ['row-zvqh~ewv3_em4a',
#    '00000000-0000-0000-CBFF-9B91C0909EB8',
#    0,
#    1591991808,
#    None,
#    1591991808,
#    None,
#    '{ }',
#    '2020-06-01T21:19:24',
#    '2020-00026529',
#    'TOUCHLESS',
#    None,
#    '-361',
#    '-361',
#    'T',
#    'Black',
#    'Male',
#    '30-39',
#    'Traffic',
#    'Warning',
#    'No Search'],
#   ['row-zuin_cz5p-872b',
#    '00000000-0000-0000-C199-D66888C67D30',
#    0,
#    1598605226,
#    None,
#    1598605226,
#    None,
#    '{ }',
#    '2017-12-31T00:22:19',
#    '2017-00078993',
#    'DURANT AVE / FULTON ST',
#    'BERKELEY',
#    '37.866930367',
#    '-122.265808619',
#    'T',
#    'Other',
#    'Male',
#    '18-29',
#    'Traffic',
#    'Warning',
#    'No Search'],
#   ['row-ccgc_rdag_crjp',
#    '00000000-0000-0000-013A-A73CF86582D3',
#    0,
#    1591991808,
#    None,
#    1591991808,
#    None,
#    '{ }',
#    '2020-05-30T23:56:46',
#    '2020-00026227',
#    'SHATTUCK AVE / CHANNING WAY',
#    'BERKELEY',
#    '37.865779797',
#    '-122.267576002',
#    'T',
#    'Black',
#    'Male',
#    '18-29',
#    'Traffic',
#    'Warning',
#    'No Search'],
#   ['row-mvy6~brih_cqvf',
#    '00000000-0000-0000-219B-C927B13A5B2A',
#    0,
#    1591991808,
#    None,
#    1591991808,
#    None,
#    '{ }',
#    '2015-09-29T10:16:51',
#    '2015-00057492',
#    '7TH ST / DWIGHT WAY',
#    'BERKELEY',
#    '37.860196423',
#    '-122.294054192',
#    'T',
#    'Other',
#    'Female',
#    '18-29',
#    'Traffic',
#    'Citation',
#    'No Search'],
#   ['row-46ic-72nr~gygz',
#    '00000000-0000-0000-6A14-866E9B106E1C',
#    0,
#    1598605226,
#    None,
#    1598605226,
#    None,
#    '{ }',
#    '2017-03-05T00:19:17',
#    '2017-00012380',
#    '920 HEINZ AVE',
#    'BERKELEY',
#    '37.853329093',
#    '-122.290301603',
#    '1196',
#    'White',
#    'Male',
#    '>40',
#    'Investigation',
#    'Warning',
#    'No Search'],
#   ['row-45sq.265f.7rjm',
#    '00000000-0000-0000-D351-5F73AE6EFC8D',
#    0,
#    1591991808,
#    None,
#    1591991808,
#    None,
#    '{ }',
#    '2020-05-30T14:15:56',
#    '2020-00026144',
#    'CHANNING WAY / 4TH ST',
#    'BERKELEY',
#    '37.86129997',
#    '-122.297843449',
#    '1196',
#    'White',
#    'Female',
#    '30-39',
#    'Traffic',
#    'Warning',
#    'No Search'],
#   ['row-6sjh~36cz~z73b',
#    '00000000-0000-0000-3D1D-DB895FFD9D70',
#    0,
#    1591991808,
#    None,
#    1591991808,
#    None,
#    '{ }',
#    '2017-04-13T12:32:51',
#    '2017-00020491',
#    'HEARST AVE / 4TH ST',
#    'BERKELEY',
#    '37.868876205',
#    '-122.300284494',
#    'T',
#    'White',
#    'Female',
#    '>40',
#    'Traffic',
#    'Citation',
#    'No Search'],
#   ['row-wt9f~qhvd~f8km',
#    '00000000-0000-0000-0555-3684D0CCA4A4',
#    0,
#    1591991808,
#    None,
#    1591991808,
#    None,
#    '{ }',
#    '2020-06-01T22:33:33',
#    '2020-00026550',
#    'CHANN 7',
#    None,
#    '-361',
#    '-361',
#    'T',
#    'Black',
#    'Male',
#    '18-29',
#    'Traffic',
#    'Warning',
#    'No Search'],
#   ['row-v6rm_h22q.6jgw',
#    '00000000-0000-0000-1CB6-E8B6A9572627',
#    0,
#    1591991808,
#    None,
#    1591991808,
#    None,
#    '{ }',
#    '2020-05-23T18:21:42',
#    '2020-00025143',
#    'HASTE ST / MILVIA ST',
#    'BERKELEY',
#    '37.864554177',
#    '-122.269904554',
#    'T',
#    'Hispanic',
#    'Male',
#    '30-39',
#    'Traffic',
#    'Warning',
#    'No Search'],
#   ['row-zjzy_mnns.j5u3',
#    '00000000-0000-0000-8C97-CB7B36F1D6ED',
#    0,
#    1591991808,
#    None,
#    1591991808,
#    None,
#    '{ }',
#    '2020-05-31T21:30:04',
#    '2020-00026335',
#    'SHATTUCK AVE / HASTE ST',
#    'BERKELEY',
#    '37.864876252',
#    '-122.267474777',
#    'T',
#    'Black',
#    'Male',
#    '<18',
#    'Traffic',
#    'Warning',
#    'No Search'],
#   ['row-nukr~r2ka_i6ub',
#    '00000000-0000-0000-88ED-7E594CFB7648',
#    0,
#    1591991808,
#    None,
#    1591991808,
#    None,
#    '{ }',
#    '2020-06-05T17:55:13',
#    '2020-00027286',
#    '1283 2ND ST',
#    'BERKELEY',
#    '37.878824198',
#    '-122.305845241',
#    'T',
#    'White',
#    'Female',
#    '30-39',
#    'Traffic',
#    'Warning',
#    'No Search'],
#   ['row-q76p.7ksg~gfus',
#    '00000000-0000-0000-B880-B42FB3B7E1DE',
#    0,
#    1591991808,
#    None,
#    1591991808,
#    None,
#    '{ }',
#    '2020-06-03T23:56:51',
#    '2020-00027012',
#    'ALLSTON WAY / 6TH ST',
#    'BERKELEY',
#    '37.865261192',
#    '-122.296783947',
#    'T',
#    'Black',
#    'Female',
#    '18-29',
#    'Traffic',
#    'Warning',
#    'No Search'],
#   ['row-s2wh~q4az~wqqf',
#    '00000000-0000-0000-4BCA-7CC87E0B37C8',
#    0,
#    1591991808,
#    None,
#    1591991808,
#    None,
#    '{ }',
#    '2020-06-02T21:07:45',
#    '2020-00026741',
#    'SAN P/HEARST',
#    None,
#    '-361',
#    '-361',
#    'T',
#    'Black',
#    'Male',
#    '30-39',
#    'Traffic',
#    'Warning',
#    'Search'],
#   ...]}

# %% [markdown]
# ### We can now examine what keys are in the top level json object
#
# We can list the keys to determine what data is stored in the object.

# %%
stops_json.keys()
# Out:
# dict_keys(['meta', 'data'])

# %% [markdown]
# ***
# Observation
# ***
# The JSON dictionary contains a `meta` key which likely refers to meta data (data about the data).  Meta data often maintained with the data and can be a good source of additional information.

# %% [markdown]
# ## Digging into Meta Data
#
# We can investigate the meta data further by examining the keys associated with the metadata.

# %%
stops_json['meta'].keys()
# Out:
# dict_keys(['view'])

# %% [markdown]
# The `meta` key contains another dictionary called `view`.  This likely refers to meta-data about a particular "view" of some underlying database.  We will learn more about views as we study SQL later in the class.
#
# 元键**包含另一个名为view的字典**。这可能是指一些底层数据库的特定“视图”的元数据。在后面的课程中，我们将学习更多关于视图的知识。

# %%
stops_json['meta']['view'].keys()
# Out:
# dict_keys(['id', 'name', 'attribution', 'averageRating', 'category', 'createdAt', 'description', 'displayType', 'downloadCount', 'hideFromCatalog', 'hideFromDataJson', 'licenseId', 'newBackend', 'numberOfComments', 'oid', 'provenance', 'publicationAppendEnabled', 'publicationDate', 'publicationGroup', 'publicationStage', 'rowsUpdatedAt', 'rowsUpdatedBy', 'tableId', 'totalTimesRated', 'viewCount', 'viewLastModified', 'viewType', 'approvals', 'columns', 'grants', 'license', 'metadata', 'owner', 'query', 'rights', 'tableAuthor', 'tags', 'flags'])

# %% [markdown]
# Notice that this a nested/recursive data structure.  As we dig deeper we reveal more and more keys and the corresponding data:
#
# 注意，这是一个嵌套/递归数据结构。随着我们深入挖掘，我们揭示了越来越多的密钥和相应的数据:
#
# ```
# meta
# |-> data
#     | ... (haven't explored yet)
# |-> view
#     | -> id
#     | -> name
#     | -> attribution
#     ...
# ```

# %% [markdown]
# There is a key called description in the view sub dictionary.  This likely contains a description of the data:

# %%
print(stops_json['meta']['view']['description'])
# Out:
# This data was extracted from the Department’s Public Safety Server and covers data beginning January 26, 2015.  On January 26, 2015 the department began collecting data pursuant to General Order B-4 (issued December 31, 2014). Under that Order, officers were required to provide certain data after making any detention (vehicle, bicycle, pedestrian, suspicious auto).  This dataset provides information about detentions, including the race, sex, age range, of the person detained; the reason for the stop; the type of enforcement taken (if any), and whether or not a search was conducted.  Also provided are the date, time, location of the detention, as well as the incident number and call for service type.

# %% [markdown]
# ### Columns Meta data
#
# Another potentially useful key in the meta data dictionary is the `columns`.  This returns a list:
#
# 元数据字典中另一个可能有用的键是列。返回一个列表:

# %%
type(stops_json['meta']['view']['columns'])
# Out:
# list

# %% [markdown]
# We can browse summary data in the list using python:

# %%
for c in stops_json['meta']['view']['columns']:
    top = ""
    items = ""
    if "cachedContents" in c:
        top = c["cachedContents"]["top"]
        for i in top:
            items = items + "\n\t" + i["item"] + ":" + i["count"]
    print(c["name"], ":", items)
# Out:
# sid :
# id :
# position :
# created_at :
# created_meta :
# updated_at :
# updated_meta :
# meta :
# CreateDatetime :
# 	2015-06-11T06:48:26.000:10
# 	2020-02-13T08:10:43.000:6
# 	2017-01-26T11:10:06.000:6
# 	2020-01-07T08:15:40.000:6
# 	2016-07-03T23:45:04.000:5
# 	2015-02-01T19:33:13.000:5
# 	2016-06-11T19:55:36.000:5
# 	2015-11-16T07:19:28.000:5
# 	2016-04-19T00:50:19.000:5
# 	2016-03-25T01:13:14.000:5
# 	2017-01-06T00:25:16.000:5
# 	2016-12-22T23:58:59.000:5
# 	2016-07-19T02:51:56.000:4
# 	2015-11-09T22:17:36.000:4
# 	2015-12-19T02:11:34.000:4
# 	2016-07-21T02:03:22.000:4
# 	2017-06-29T02:15:29.000:4
# 	2018-07-02T21:36:29.000:4
# 	2016-05-25T01:20:06.000:4
# 	2016-05-01T01:23:53.000:4
# IncidentNumber :
# 	2020-00001049:6
# 	2020-00008547:6
# 	2015-00033565:5
# 	2016-00039405:5
# 	2016-00017339:5
# 	2016-00075241:5
# 	2016-00034574:5
# 	2017-00000828:5
# 	2015-00033576:5
# 	2015-00067321:5
# 	2015-00006347:5
# 	2016-00022806:5
# 	2016-00030608:4
# 	2019-00025759:4
# 	2016-00049625:4
# 	2018-00010987:4
# 	2015-00033137:4
# 	2017-00045853:4
# 	2016-00042412:4
# 	2017-00057823:4
# Address :
# 	UNIVERSITY AVE / 6TH ST:525
# 	UNIVERSITY AVE / SAN PABLO AVE:472
# 	ASHBY AVE / 7TH ST:449
# 	6TH ST / UNIVERSITY AVE:449
# 	7TH ST / POTTER ST:372
# 	UNIVERSITY AVE / MARTIN LUTHER KING JR WAY:360
# 	ASHBY AVE / SAN PABLO AVE:351
# 	80 BOLIVAR DR:349
# 	SAN PABLO AVE / UNIVERSITY AVE:340
# 	UNIVERSITY AVE / FRONTAGE RD:320
# 	7TH ST / ASHBY AVE:311
# 	UNIVERSITY AVE / ACTON ST:296
# 	UNIVERSITY AVE / SACRAMENTO ST:295
# 	SHATTUCK AVE / KITTREDGE ST:272
# 	UNIVERSITY AVE / BONAR ST:242
# 	SAN PABLO AVE / ASHBY AVE:231
# 	POTTER ST / 7TH ST:217
# 	UNIVERSITY AVE / 7TH ST:214
# 	1998 SHATTUCK AVE:211
# 	UNIVERSITY AVE / SHATTUCK AVE:204
# City :
# 	BERKELEY:53060
# 	OAKLAND:1818
# 	EMERYVILLE:316
# 	ALBANY:129
# 	Berkeley:2
# Lat :
# 	-361:2958
# 	37.867993895:974
# 	37.869096588:812
# 	37.851008554:760
# 	37.851514871:589
# 	37.852140636:582
# 	37.871555258:500
# 	37.870410562:410
# 	37.868489249:396
# 	37.872151446:394
# 	37.866444425:392
# 	37.853281083:355
# 	37.870112645:349
# 	37.864546214:349
# 	37.868202006:335
# 	37.854316382:335
# 	37.851615813:311
# 	37.8693028530001:289
# 	37.865779797:269
# 	37.869696081:265
# Lon :
# 	-361:2958
# 	-122.297664389:974
# 	-122.292119433:812
# 	-122.291104028:760
# 	-122.291270411:589
# 	-122.286683357:582
# 	-122.273001335:500
# 	-122.281937988:410
# 	-122.267867519:396
# 	-122.26841392:394
# 	-122.305556167:392
# 	-122.279011568:355
# 	-122.301738812:349
# 	-122.284248929:349
# 	-122.29662475:335
# 	-122.271084145:335
# 	-122.289369289:311
# 	-122.272234021:289
# 	-122.267576002:269
# 	-122.287499477:265
# CallType :
# 	T:46101
# 	1194:6873
# 	1196:3247
# 	1194B:2497
# Race :
# 	White:20544
# 	Black:19776
# 	Hispanic:7534
# 	Other:5885
# 	Asian:4621
# 	0:358
# Gender :
# 	Male:41115
# 	Female:17245
# 	0:358
# Age :
# 	>40:21829
# 	18-29:19276
# 	30-39:15822
# 	<18:1433
# 	0:358
# Reason :
# 	Traffic:49525
# 	Investigation:5329
# 	Reas. Susp.:2307
# 	Prob./Parole:984
# 	0:358
# 	Wanted:211
# Enforcement :
# 	Warning:35217
# 	Citation:20262
# 	Arrest:1930
# 	Other:951
# 	0:358
# Car Search :
# 	No Search:49500
# 	Search:8860
# 	0:358

# %% [markdown]
# ### Observations?
#
# 1. The above meta data tells us a lot about the columns in the data including column names, potential data anomalies, and a basic statistic.
# 1. The old version of this data included descriptions which would be useful in loading and working with the data.
# 1. JSON makes it easier (than CSV) to create "self-documented data".
# 1. Self documenting data can be helpful since it maintains it's own description and these descriptions are more likely to be updated as data changes.

# %% [markdown]
# ### Examining the Data Field
#
# We can look at a few entires in the data field

# %%
for i in range(3):
    print(i, "\t", stops_json['data'][i])
# Out:
# 0 	 ['row-2j6s.qe6z_jtkn', '00000000-0000-0000-D599-E1C6017B6966', 0, 1589533219, None, 1589533219, None, '{ }', '2017-05-02T20:50:29', '2017-00024695', '1275 WALNUT ST', 'BERKELEY', '37.88452086', '-122.268652364', '1194', 'White', 'Female', '30-39', 'Investigation', 'Warning', 'No Search']
# 1 	 ['row-79rz~ucps-35r6', '00000000-0000-0000-B83C-7A2ADDC55727', 0, 1598605226, None, 1598605226, None, '{ }', '2018-02-20T18:42:04', '2018-00010451', '2176 KITTREDGE ST', 'BERKELEY', '37.868233788', '-122.266394615', '1194', 'White', 'Male', '>40', 'Investigation', 'Other', 'No Search']
# 2 	 ['row-tmr9_n9ye.6bzh', '00000000-0000-0000-3120-DC62279E5799', 0, 1598605226, None, 1598605226, None, '{ }', '2020-03-04T16:18:11', '2020-00012764', '1414 UNIVERSITY AVE', 'BERKELEY', '37.869690714', '-122.283865643', 'T', 'Black', 'Female', '>40', 'Traffic', 'Citation', 'No Search']

# %% [markdown]
# ## Building a Dataframe from JSON

# %% [markdown]
# In the following block of code we:
# 1. Translate the JSON records into a dataframe
# 1. Remove columns that have no metadata description.  This would be a bad idea in general but here we remove these columns since the above analysis suggests that they are unlikely to contain useful information.
# 1. Examine the top of the table

# %%
# Load the data from JSON and assign column titles
stops = pd.DataFrame(
    stops_json['data'],
    columns=[c['name'] for c in stops_json['meta']['view']['columns']])

stops.head()
# Out:
#                   sid                                    id  position  \
# 0  row-2j6s.qe6z_jtkn  00000000-0000-0000-D599-E1C6017B6966         0
# 1  row-79rz~ucps-35r6  00000000-0000-0000-B83C-7A2ADDC55727         0
# 2  row-tmr9_n9ye.6bzh  00000000-0000-0000-3120-DC62279E5799         0
# 3  row-cjve_43yp_s8ec  00000000-0000-0000-4EEF-F940D151C603         0
# 4  row-wxqp_6mgh-v4r5  00000000-0000-0000-8B94-7D86EB47C51D         0
#
#    created_at created_meta  updated_at updated_meta meta       CreateDatetime  \
# 0  1589533219         None  1589533219         None  { }  2017-05-02T20:50:29
# 1  1598605226         None  1598605226         None  { }  2018-02-20T18:42:04
# 2  1598605226         None  1598605226         None  { }  2020-03-04T16:18:11
# 3  1598605226         None  1598605226         None  { }  2018-12-04T15:11:14
# 4  1589533219         None  1589533219         None  { }  2020-05-13T09:37:53
#
#   IncidentNumber  ...      City           Lat             Lon CallType  \
# 0  2017-00024695  ...  BERKELEY   37.88452086  -122.268652364     1194
# 1  2018-00010451  ...  BERKELEY  37.868233788  -122.266394615     1194
# 2  2020-00012764  ...  BERKELEY  37.869690714  -122.283865643        T
# 3  2018-00067166  ...  BERKELEY  37.867138358  -122.268229602     1196
# 4  2020-00023435  ...  BERKELEY  37.865779797  -122.267576002     1194
#
#        Race  Gender    Age         Reason Enforcement Car Search
# 0     White  Female  30-39  Investigation     Warning  No Search
# 1     White    Male    >40  Investigation       Other  No Search
# 2     Black  Female    >40        Traffic    Citation  No Search
# 3  Hispanic    Male  30-39        Traffic     Warning  No Search
# 4     Black    Male    >40        Traffic    Citation  No Search
#
# [5 rows x 21 columns]

# %%
stops.columns
# Out:
# Index(['sid', 'id', 'position', 'created_at', 'created_meta', 'updated_at',
#        'updated_meta', 'meta', 'CreateDatetime', 'IncidentNumber', 'Address',
#        'City', 'Lat', 'Lon', 'CallType', 'Race', 'Gender', 'Age', 'Reason',
#        'Enforcement', 'Car Search'],
#       dtype='object')

# %% [markdown]
# ## Preliminary Observations
#
# What do we observe so far?

# %% [markdown]
# We observe:
# 1. The `Incident Number` appears to have the year encoded in it - we could potentially use this as a validation check.
# 1. The `created_at` and `updated_at` Fields look like they are in milliseconds since January 1, 1970.
# 1. The `CreateDatetime` Field looks to be formatted in YYYY-MM-DDTHH:MM:SS.  I am guessing T means "Time".
# 1. The `Age` Field has variable size brackets: 18-29, 30-39, >40.

# %% [markdown]
# # Exploration
#
# Now that we have loaded our various data files.  Let's try to understand a bit more about the data by examining properties of individual fields.

# %%
calls.head()
# Out:
#      CASENO                   OFFENSE                 EVENTDT EVENTTM  \
# 0  19092769  THEFT MISD. (UNDER $950)  12/09/2019 12:00:00 AM   13:00
# 1  19045891                 NARCOTICS  08/18/2019 12:00:00 AM   17:20
# 2  19060215     ASSAULT/BATTERY MISD.  10/23/2019 12:00:00 AM   10:45
# 3  19092681                 VANDALISM  12/01/2019 12:00:00 AM   18:40
# 4  19044228     ASSAULT/BATTERY MISD.  08/10/2019 12:00:00 AM   22:51
#
#          CVLEGEND  CVDOW                InDbDate  \
# 0         LARCENY      1  09/10/2020 07:00:11 AM
# 1  DRUG VIOLATION      0  09/10/2020 07:00:08 AM
# 2         ASSAULT      3  09/10/2020 07:00:10 AM
# 3       VANDALISM      0  09/10/2020 07:00:11 AM
# 4         ASSAULT      6  09/10/2020 07:00:08 AM
#
#                                       Block_Location  \
# 0                         SHATTUCK AVE\nBerkeley, CA
# 1           FRONTAGE STREET &GILMAN ST\nBerkeley, CA
# 2  2200 MILVIA ST\nBerkeley, CA\n(37.868574, -122...
# 3                          VIRGINIA ST\nBerkeley, CA
# 4          UNIVERSITY AVENUE &FRONTAGE\nBerkeley, CA
#
#                        BLKADDR      City State        Day
# 0                 SHATTUCK AVE  Berkeley    CA     Monday
# 1   FRONTAGE STREET &GILMAN ST  Berkeley    CA     Sunday
# 2               2200 MILVIA ST  Berkeley    CA  Wednesday
# 3                  VIRGINIA ST  Berkeley    CA     Sunday
# 4  UNIVERSITY AVENUE &FRONTAGE  Berkeley    CA   Saturday

# %% [markdown]
# ### Are Case Numbers unique?
#
# Case numbers are probably used internally to track individual cases and my reference other data we don't have access to.  However, it is possible that multiple calls could be associated with the same case.  Let's see if the case numbers are all unique.

# %%
print("There are", calls['CASENO'].unique().shape[0], "unique case numbers.")
print("There are", calls.shape[0], "calls in the table.")
# Out:
# There are 5227 unique case numbers.
# There are 5227 calls in the table.

# %% [markdown]
# ### Are there any other interesting temporal patterns
#
# Do more calls occur on a particular day of the week?

# %%
dow = ["Sunday", "Monday", "Tuesday", "Wednesday", "Thursday", "Friday", "Saturday"]
calls.groupby('Day')['CASENO'].count()[dow]
# Out:
# Day
# Sunday       660
# Monday       788
# Tuesday      730
# Wednesday    751
# Thursday     771
# Friday       778
# Saturday     749
# Name: CASENO, dtype: int64

# %% [markdown]
# ### Examining the Event
#
# We also have data about the different kinds of crimes being reported

# %%
calls.head()
# Out:
#      CASENO                   OFFENSE                 EVENTDT EVENTTM  \
# 0  19092769  THEFT MISD. (UNDER $950)  12/09/2019 12:00:00 AM   13:00
# 1  19045891                 NARCOTICS  08/18/2019 12:00:00 AM   17:20
# 2  19060215     ASSAULT/BATTERY MISD.  10/23/2019 12:00:00 AM   10:45
# 3  19092681                 VANDALISM  12/01/2019 12:00:00 AM   18:40
# 4  19044228     ASSAULT/BATTERY MISD.  08/10/2019 12:00:00 AM   22:51
#
#          CVLEGEND  CVDOW                InDbDate  \
# 0         LARCENY      1  09/10/2020 07:00:11 AM
# 1  DRUG VIOLATION      0  09/10/2020 07:00:08 AM
# 2         ASSAULT      3  09/10/2020 07:00:10 AM
# 3       VANDALISM      0  09/10/2020 07:00:11 AM
# 4         ASSAULT      6  09/10/2020 07:00:08 AM
#
#                                       Block_Location  \
# 0                         SHATTUCK AVE\nBerkeley, CA
# 1           FRONTAGE STREET &GILMAN ST\nBerkeley, CA
# 2  2200 MILVIA ST\nBerkeley, CA\n(37.868574, -122...
# 3                          VIRGINIA ST\nBerkeley, CA
# 4          UNIVERSITY AVENUE &FRONTAGE\nBerkeley, CA
#
#                        BLKADDR      City State        Day
# 0                 SHATTUCK AVE  Berkeley    CA     Monday
# 1   FRONTAGE STREET &GILMAN ST  Berkeley    CA     Sunday
# 2               2200 MILVIA ST  Berkeley    CA  Wednesday
# 3                  VIRGINIA ST  Berkeley    CA     Sunday
# 4  UNIVERSITY AVENUE &FRONTAGE  Berkeley    CA   Saturday

# %% [markdown]
# ### The Offense Field
#
# The Offense field appears to contain the specific crime being reported.  As nominal data we might want to see a summary constructed by computing counts of each offense type:

# %%
calls['OFFENSE'].value_counts().plot(kind = 'bar')
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### Observations?

# %% [markdown]
# Car burglary and misdemeanor theft seem to be the most common crimes with many other types of crimes occurring rarely.

# %% [markdown]
# ### CVLEGEND
#
# The CVLEGEND field provides the broad category of crime and is a good mechanism to group potentially similar crimes.

# %%
calls['CVLEGEND'].value_counts().plot(kind="bar")
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Advanced: Examine data geographically

# %%
import folium
import folium.plugins # The Folium Javascript Map Library

SF_COORDINATES = (37.87, -122.28)
sf_map = folium.Map(location=SF_COORDINATES, zoom_start=13)
locs = calls_lat_lon[['Lat', 'Lon']].astype('float').dropna().to_numpy()
heatmap = folium.plugins.HeatMap(locs.tolist(), radius = 10)
sf_map.add_child(heatmap)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-103-886418bd6d9b> in <module>
# ----> 1 import folium
#       2 import folium.plugins # The Folium Javascript Map Library
#       3
#       4 SF_COORDINATES = (37.87, -122.28)
#       5 sf_map = folium.Map(location=SF_COORDINATES, zoom_start=13)
#
# ModuleNotFoundError: No module named 'folium'
