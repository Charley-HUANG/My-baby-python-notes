# %% [markdown]
# <p style="font-size:15pt; text-align:center">
#     Introduction to Data Science
# </p>
# <p style="font-size:20pt; text-align:center">
#     Network analyis and visualization
# </p>

# %% [markdown]
# # Importing required modules

# %%
import numpy as np
import networkx as nx
import matplotlib.pyplot as plt
import matplotlib as mpl
# %matplotlib inline

# %% [markdown]
# # Basic data types in NetworkX
# NetworkX provides the following classes that represent network-related data,
# as well as network analysis algorithms that operate on these objects:

# %% [markdown]
# **Graph**       - Undirected graph with self loops

# %% [markdown]
# **DiGraph**      - Directed graph with self loops

# %% [markdown]
# **MultiGraph**   - Undirected Graph with self loops and multiple edges

# %% [markdown]
# **MultiDiGraph** - Directed Graph with self loops and multiple edges

# %% [markdown]
# # Getting started
# Create an empty, undirected network

# %%
G = nx.Graph()

# %% [markdown]
# # Nodes
# Nodes can be almost anything, including numbers, strings, GPS coordinates, you name it.

# %% [markdown]
# Nodes can be added one at a time:

# %%
G.add_node(0)
G.add_node("John")

# tuple object representing, say, longitude and latitude
pos = (1.2, 3.4) 
G.add_node(pos)

# %% [markdown]
# ...or many at once from a python container

# %%
# [1,2,3] is a list containing 1, 2, and 3
G.add_nodes_from([1, 2, 3])

# %% [markdown]
# # Node attributes
# Nodes can have arbitrary attributes associated with them, contained in a string-index dictionary

# %% [markdown]
# Adding attributes at the time of node creation using keyword arguments:

# %%
G.add_node("Michael", eye_color='brown', height=180)

# %% [markdown]
# You can also add attributes to an already existing node

# %%
G.add_node("Natalie")

# add an attribute "books" with value 500 to Natalie
G.nodes["Natalie"]["books"] = 500

# %% [markdown]
# G.node[n] gives a dictionary containing all the attribute:value pairs associated with node n

# %%
print("Michael's eyes are ", G.nodes["Michael"]["eye_color"], " and he is ", G.nodes['Michael']['height'], " cm tall.")
print("Natalie has ", G.nodes["Natalie"]["books"], " books.")
# Out:
# Michael's eyes are  brown  and he is  180  cm tall.
# Natalie has  500  books.

# %% [markdown]
# # Edges
#
# An edge between node1 and node2 is represented by a tuple (node1, node2)
# They can be added one at a time:

# %%
# add edge between node 0 and node 1
G.add_edge(0, 1)

# %% [markdown]
# Or many at once from a container

# %%
edge_list = [ (2, 1), ("Michael", "Natalie"), (3, 4) ]
G.add_edges_from(edge_list)
print(list(G.nodes))
print(list(G.edges))
# Out:
# [0, 'John', (1.2, 3.4), 1, 2, 3, 'Michael', 'Natalie', 4]
# [(0, 1), (1, 2), (3, 4), ('Michael', 'Natalie')]

# %% [markdown]
# **Note:** Nodes will be automatically created if they don't already exist.

# %% [markdown]
# # Edge attributes
# Like nodes, edges can also have arbitrary attributes. An important and special one (for many algorithms) is "weight"
#
# The syntax for adding/accessing edge attributes is the similar to that for nodes:

# %%
G.add_edge("Michael", "Natalie", weight=10)
G["Michael"]["Natalie"]
# Out:
# {'weight': 10}

# %% [markdown]
# `G[node1][node2]` is a dictionary containing all attribute:value pairs associated with the edge from node1 to node2

# %%
G.add_edge("Copenhagen", "Aarhus")
attrs = {("Copenhagen", "Aarhus"): {'distance': 186.7}}
nx.set_edge_attributes(G, attrs)

print(list(G.edges))
print(G["Copenhagen"]["Aarhus"]['distance'])
print(G.get_edge_data("Copenhagen", "Aarhus"))
# Out:
# [(0, 1), (1, 2), (3, 4), ('Michael', 'Natalie'), ('Copenhagen', 'Aarhus')]
# 186.7
# {'distance': 186.7}

# %% [markdown]
# # Basic operations

# %% [markdown]
# ### Size of the network

# %%
# number of nodes
print(G.number_of_nodes())

# another way
print(len(G))

# number of edges
print(G.number_of_edges())

# another way
print(G.size())

print("G has {0} nodes and {1} edges.".format(len(G), G.size()))
# Out:
# 11
# 11
# 5
# 5
# G has 11 nodes and 5 edges.

# %% [markdown]
# ### Testing to see whether nodes or edges exist

# %%
G.has_node("Michael")
# Out:
# True

# %% [markdown]
# Another way:

# %%
"Natalie" in G
# Out:
# True

# %% [markdown]
# For edges, you must use `has_edge()` (no syntax like `edge in G`)

# %%
print(G.has_edge(3, 4))
print(G.has_edge("Michael", 0))
# Out:
# True
# False

# %% [markdown]
# ### Finding neighbors of a node

# %%
list(G.neighbors(1))
# Out:
# [0, 2]

# %% [markdown]
# * In `DiGraph` objects, `G.neighbors(node)` gives the successors of `node`, as does `G.successors(node)`
# * Predecessors of `node` can be obtained with `G.predecessors(node)`

# %% [markdown]
# ### Iterating over nodes and edges
# Nodes and edges can be iterated over with `G.nodes()` and `G.edges()` respectively

# %%
for node, data in list(G.nodes(data=True)): # data=True includes node attributes as dictionaries
    print("Node {0}\t\t\t: {1}".format(node, data))
# Out:
# Node 0			: {}
# Node John			: {}
# Node (1.2, 3.4)			: {}
# Node 1			: {}
# Node 2			: {}
# Node 3			: {}
# Node Michael			: {'eye_color': 'brown', 'height': 180}
# Node Natalie			: {'books': 500}
# Node 4			: {}
# Node Copenhagen			: {}
# Node Aarhus			: {}

# %%
for n1, n2, data in list(G.edges(data=True)):
    print("{0} <----> {1}: {2}".format(n1, n2, data))
# Out:
# 0 <----> 1: {}
# 1 <----> 2: {}
# 3 <----> 4: {}
# Michael <----> Natalie: {'weight': 10}
# Copenhagen <----> Aarhus: {'distance': 186.7}

# %% [markdown]
# ### Calculating degrees

# %%
# one node
print(G.degree("Michael")) # returns an integer

# all nodes (returns a dictionary with node : degree pairs for all nodes)
print(G.degree())

# just the degree sequence
degree_sequence = [d for _, d in G.degree()]
print(degree_sequence)
# Out:
# 1
# [(0, 1), ('John', 0), ((1.2, 3.4), 0), (1, 2), (2, 1), (3, 1), ('Michael', 1), ('Natalie', 1), (4, 1), ('Copenhagen', 1), ('Aarhus', 1)]
# [1, 0, 0, 2, 1, 1, 1, 1, 1, 1, 1]

# %% [markdown]
# As you know, in directed graphs (of class `DiGraph`) there are two types of degree. Things work just as you expect
# * `G.in_degree(node) `
# * `G.out_degree(node) # same as G.degree()`

# %% [markdown]
# # Other operations

# %% [markdown]
# * ***`subgraph(G, nbunch)` or `G.subgraph(nbunch)`***
# subgraph of G induced by nodes in nbunch
#
# * ***`reverse(G)`***
# DiGraph with edges reversed
#
# * ***`union(G1, G2)`***
# graph union
#
# * ***`disjoint_union(G1, G2)`***
# same, but treats nodes of G1, G2 as different
#
# * ***`intersection(G1, G2)`***
# graph with only the edges in common between G1, G2
#
# * ***`difference(G1, G2)`***
# graph with only the edges G1 that aren't in G2
#
# * ***`copy(G)` or `G.copy()`***
# copy of G
#
# * ***`complement(G)` or `G.complement()`***
# the complement graph of G
#
# * ***`convert_to_undirected(G)` or `G.to_undirected()`***
# undirected version of G (a Graph or MultiGraph)
#
# * ***`convert_to_directed(G)` or `G.to_directed()`***
# directed version of G (a DiGraph of MultiDiGraph)
#
# * ***`adjacency_matrix(G)`***
# adjacency matrix A of G (in sparse matrix format; to get full matrix, use A.toarray() )

# %% [markdown]
# # Graph I/O
#
# Usually you will not be building a network from scratch one node/link at a time. Instead, you will
# want to read it in from an appropriate data file. NetworkX can understand the following common graph
# formats:

# %% [markdown]
# * edge lists
# * adjacency lists
# * GML
# * GEXF
# * Python 'pickle'
# * GraphML
# * Pajek
# * LEDA
# * YAML

# %% [markdown]
# # Getting started: reading in an edge list
#
# Read in the file `test.txt` with the following options
# * lines starting with `#` are treated as comments and ignored
# * use a `Graph` object to hold the data (i.e., network is undirected)
# * data are separated by whitespace (' ')
# * nodes should be treated as integers (`int`)
# * encoding of the text file containing the edge list is utf-8

# %%
# read in an edge list from the file 'test.txt'
G = nx.read_edgelist('files/test.txt', comments='#',
                     create_using=nx.Graph(), 
                     delimiter=' ', 
                     nodetype=int, 
                     encoding='utf-8')

# %% [markdown]
# ### Allowed formats
# * Node pairs with no data
# `1 2`
# * Node pairs with python dictionary
# `1 2 {weight:7, color:"green"}`

# %% [markdown]
# # Basic analysis
# A large number of basic analyses can be done in one line using NetworkX + numpy or builtin python functions like `min`, `max`, etc.

# %%
N = len(G)
L = G.size()
degrees = [d for _, d in G.degree()]
kmin = min(degrees)
kmax = max(degrees)

# %%
print("Number of nodes: ", N)
print("Number of edges: ", L)
print()
print("Average degree: ", 2*L/N)
print("Average degree (alternate calculation)", np.mean(degrees))
print()
print("Minimum degree: ", kmin)
print("Maximum degree: ", kmax)
# Out:
# Number of nodes:  443
# Number of edges:  540
#
# Average degree:  2.4379232505643342
# Average degree (alternate calculation) 2.4379232505643342
#
# Minimum degree:  1
# Maximum degree:  8

# %% [markdown]
# # Drawing the network
# * NetworkX can draw networks using a large number of layout algorithms
# * The results are not as pretty as Gephi, but NetworkX is better for a quick 'n dirty visualization and
# gives you finer-grained control over the layout.

# %%
# using the force-based or "spring" layout algorithm
fig = plt.figure(figsize=(8,8))
nx.draw_spring(G, node_size=30)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# D:\anaconda3\lib\site-packages\networkx\utils\decorators.py in _random_state(func, *args, **kwargs)
#     395         try:
# --> 396             random_state_arg = args[random_state_index]
#     397         except TypeError as e:
#
# IndexError: tuple index out of range
#
# The above exception was the direct cause of the following exception:
#
# NetworkXError                             Traceback (most recent call last)
# <ipython-input-61-587ed1aa4752> in <module>
#       1 # using the force-based or "spring" layout algorithm
#       2 fig = plt.figure(figsize=(8,8))
# ----> 3 nx.draw_spring(G, node_size=30)
#
# D:\anaconda3\lib\site-packages\networkx\drawing\nx_pylab.py in draw_spring(G, **kwargs)
#    1164        function.
#    1165     """
# -> 1166     draw(G, spring_layout(G), **kwargs)
#    1167
#    1168
#
# D:\anaconda3\lib\site-packages\decorator.py in fun(*args, **kw)
#     229             if not kwsyntax:
#     230                 args, kw = fix(args, kw, sig)
# --> 231             return caller(func, *(extras + args), **kw)
#     232     fun.__name__ = func.__name__
#     233     fun.__doc__ = func.__doc__
#
# D:\anaconda3\lib\site-packages\networkx\utils\decorators.py in _random_state(func, *args, **kwargs)
#     398             raise nx.NetworkXError("random_state_index must be an integer") from e
#     399         except IndexError as e:
# --> 400             raise nx.NetworkXError("random_state_index is incorrect") from e
#     401
#     402         # Create a numpy.random.RandomState instance
#
# NetworkXError: random_state_index is incorrect

# %%
# using the fcircular layout algorithm
fig = plt.figure(figsize=(8,8))
nx.draw_circular(G, node_size=30)

# %% [markdown]
# # Plotting the degree distribution

# %% [markdown]
# Let's plot it in log scale first with log-binning, using `np.logspace` and `np.histogram`:

# %%
fig = plt.figure(figsize=(4, 3))
axes = fig.add_axes([0, 0, 1, 1])

logbins = np.logspace(np.log10(kmin), np.log10(kmax), num=10)
h, binedges = np.histogram(degrees,  bins=logbins, density=True) # We use np.histogram to make the binning calculations. Plotting is done with axes.plot below.
binmidpoints = (binedges[1:] + binedges[:-1]) / 2

axes.plot(binmidpoints, h, "o")
axes.set_xlabel("Degree k")
axes.set_ylabel("P(x)")
axes.set_xscale('log') 
axes.set_yscale('log')

# %% [markdown]
# This is clearly not a network with anything like a heavy-tailed degree distribution.
# So let's plot it in linear scale without any binning:

# %%
fig = plt.figure(figsize=(4, 3))
axes = fig.add_axes([0, 0, 1, 1])

# See: https://networkx.github.io/documentation/stable/auto_examples/drawing/plot_degree_histogram.html
from collections import Counter
degree_sequence = [d for _, d in G.degree()]  # degree sequence
degreeCount = Counter(degree_sequence)
print(degreeCount) # print for teaching

# Normalize
total = sum(degreeCount.values())
for key in degreeCount:
    degreeCount[key] /= total
print(degreeCount.items()) # print for teaching
    
deg, prob = zip(*degreeCount.items()) # unpacks the first tuple elements into deg, unpacks the second tuple elements into prob


axes.plot(deg, prob, "o")
axes.set_xlabel("Degree k")
axes.set_ylabel("P(k)");
# Out:
# Counter({2: 153, 1: 113, 3: 99, 4: 43, 5: 23, 6: 8, 7: 3, 8: 1})
# dict_items([(5, 0.05191873589164785), (2, 0.345372460496614), (4, 0.09706546275395034), (3, 0.2234762979683973), (1, 0.255079006772009), (8, 0.002257336343115124), (6, 0.01805869074492099), (7, 0.006772009029345372)])

# %% [markdown]
# # node importance
#
# `nx.centrality.betweenness_centrality()`
#
# `nx.centrality.degree_centrality()`
#
# `nx.centrality.closeness_centrality()`
#
# `nx.pagerank()`

# %%
nx.pagerank(G)
# Out:
# {0: 0.003674843966400407,
#  482: 0.001747182455886142,
#  162: 0.003795568812784965,
#  499: 0.0037600983927052398,
#  362: 0.0029269171416317487,
#  389: 0.002425240399138267,
#  1: 0.0022778540214262637,
#  356: 0.0019497912844493362,
#  244: 0.0013067961244547538,
#  2: 0.0020253434643867215,
#  347: 0.0019967599986890194,
#  227: 0.0029547134664055057,
#  3: 0.0040079941641513635,
#  184: 0.0017030550366138658,
#  278: 0.0016770984726861744,
#  340: 0.0020478279323145497,
#  142: 0.0024867547537323785,
#  30: 0.0023261997922335792,
#  4: 0.0011088969963598176,
#  124: 0.002718906906042769,
#  5: 0.0034624414082063903,
#  493: 0.005880453700835612,
#  65: 0.0022201347367880524,
#  319: 0.00451751027655864,
#  293: 0.005016885646579828,
#  193: 0.004383422424759222,
#  6: 0.0028091055484611785,
#  80: 0.0011342687471320619,
#  273: 0.0025352140509562996,
#  491: 0.002778928334720103,
#  7: 0.002257336343115124,
#  127: 0.002257336343115124,
#  8: 0.0017887124732273046,
#  49: 0.0034515139853260675,
#  405: 0.002530192411629997,
#  9: 0.0017070827675251853,
#  219: 0.003202072968944835,
#  85: 0.004046938159710844,
#  10: 0.0010676164043230268,
#  395: 0.0025723358276637034,
#  11: 0.0016206496495342155,
#  192: 0.0053317471655822,
#  182: 0.0044780160227109135,
#  12: 0.002745186016083814,
#  352: 0.0011163680188630654,
#  439: 0.0018416863013686448,
#  199: 0.003969949553322654,
#  13: 0.002492848266867798,
#  235: 0.002319500055076239,
#  341: 0.001045046743769629,
#  14: 0.0010259228103182737,
#  215: 0.0040415809452367555,
#  16: 0.0026582097268980347,
#  388: 0.0037396038338594366,
#  77: 0.0035585807433155797,
#  47: 0.001091913555994407,
#  17: 0.0018473760995010888,
#  435: 0.0018450828209296884,
#  167: 0.0025572002724422215,
#  19: 0.002257336343115124,
#  286: 0.002257336343115124,
#  22: 0.002086319667252163,
#  164: 0.0033244441812458675,
#  140: 0.0012255003426334611,
#  23: 0.0020096447663969226,
#  196: 0.0038645958455975284,
#  94: 0.001192447668314849,
#  24: 0.003062002023329422,
#  402: 0.0016292250979482391,
#  411: 0.0023626044734003644,
#  173: 0.0024290694637133124,
#  326: 0.00237705044620561,
#  26: 0.001100112349894541,
#  453: 0.0035826106848423555,
#  29: 0.002257336343115124,
#  97: 0.002257336343115124,
#  320: 0.0023695463194270596,
#  31: 0.0028537274490719983,
#  360: 0.0034469921845986158,
#  497: 0.002848551349385667,
#  243: 0.0011469565221369918,
#  33: 0.0012229787123827424,
#  470: 0.0020807818935799104,
#  34: 0.0023045835982446797,
#  400: 0.0013171897344501338,
#  134: 0.0039748272360275415,
#  35: 0.0010262446724739183,
#  259: 0.00404652275683665,
#  36: 0.0016786385772289288,
#  111: 0.004885748743184539,
#  37: 0.002711085028694636,
#  496: 0.0020774241139754875,
#  76: 0.005176457676218354,
#  79: 0.0026688556770684793,
#  38: 0.0009633571534623244,
#  40: 0.0010231831237945235,
#  88: 0.0040242548106478,
#  41: 0.0031752698537239857,
#  200: 0.0029913009092906516,
#  73: 0.0033515030041594597,
#  92: 0.0017448122384282935,
#  481: 0.0026348801777527275,
#  42: 0.0023612753031630107,
#  445: 0.001693052249308515,
#  486: 0.0023419860778517297,
#  44: 0.002365931271689047,
#  190: 0.001713295673980501,
#  119: 0.0023293015395510867,
#  45: 0.0028688707094644003,
#  186: 0.0022522855620287848,
#  163: 0.0027706817161407826,
#  198: 0.001850650107995478,
#  46: 0.0024195405895782863,
#  252: 0.002376219661274782,
#  48: 0.001239380988277588,
#  176: 0.0031783152017101934,
#  129: 0.0017745795365054964,
#  250: 0.002461314754503869,
#  50: 0.0024092549717290163,
#  336: 0.002384922207437181,
#  122: 0.002371198816623216,
#  51: 0.0033880821153235543,
#  224: 0.0012999633937026485,
#  434: 0.001984546066029903,
#  299: 0.0012999633937026485,
#  52: 0.0010786827789076995,
#  342: 0.003481230871340648,
#  53: 0.002257336343115124,
#  498: 0.002257336343115124,
#  54: 0.0017144946883927664,
#  474: 0.003779444152017302,
#  55: 0.0018061723668903597,
#  382: 0.0027980963662643946,
#  334: 0.003971333192432901,
#  56: 0.002706153523017906,
#  339: 0.0011054979314134795,
#  123: 0.0026074762440133313,
#  438: 0.004867331605768948,
#  57: 0.0029305770068464286,
#  177: 0.0029305770068464286,
#  451: 0.0015840956793838187,
#  58: 0.0010267600148725726,
#  59: 0.0012829343165371577,
#  120: 0.0022216131541009628,
#  60: 0.0017575898029784753,
#  385: 0.001740449497704391,
#  260: 0.0023974527739013757,
#  61: 0.0024924468127565337,
#  83: 0.0025607339410365503,
#  133: 0.0031718846161249855,
#  454: 0.0026617555731198424,
#  62: 0.0017988795873106686,
#  242: 0.0017694112954277238,
#  255: 0.0033332362334304363,
#  63: 0.0026130508410002807,
#  432: 0.0018362785800025991,
#  107: 0.0017776977439936184,
#  64: 0.0023542054145630534,
#  328: 0.0024103498111657596,
#  221: 0.002274308969327424,
#  67: 0.001076900344069275,
#  386: 0.002604895887544828,
#  68: 0.004280184499213444,
#  369: 0.001933394805285578,
#  178: 0.0017638425619699348,
#  323: 0.001881687392367605,
#  141: 0.0017975390619335574,
#  69: 0.002529049451922018,
#  401: 0.0018520040155810364,
#  70: 0.0010450386946875508,
#  99: 0.003325093015016309,
#  428: 0.0010509648418850998,
#  74: 0.0035904614912801312,
#  276: 0.002175104073574827,
#  154: 0.0021170208149971096,
#  469: 0.002449985599363611,
#  75: 0.0018328164536109454,
#  329: 0.004045325877366845,
#  132: 0.0018958057408845165,
#  214: 0.001847225866305573,
#  442: 0.001072029438459057,
#  158: 0.0031137216677804324,
#  370: 0.002164111621234933,
#  407: 0.0028512239160260917,
#  383: 0.001737253205043119,
#  78: 0.002471666019699937,
#  137: 0.0024658890474963686,
#  282: 0.0018239633900389049,
#  292: 0.002327140137331144,
#  81: 0.001239380988277588,
#  82: 0.0016746458470193325,
#  165: 0.00508401512410031,
#  139: 0.0025825807649467463,
#  477: 0.0018455481870983245,
#  272: 0.003129368971549181,
#  121: 0.0018328406220952049,
#  86: 0.0010821999010584176,
#  480: 0.003500465709041165,
#  253: 0.0037816004425145562,
#  90: 0.0023117791082709494,
#  194: 0.0029767051273423923,
#  101: 0.0023053615687541034,
#  91: 0.001146691498469244,
#  93: 0.001176278618622444,
#  96: 0.0010530607811245866,
#  268: 0.0033610637604456427,
#  98: 0.0019383965435136779,
#  426: 0.0019258184734176132,
#  335: 0.0027577132545474926,
#  289: 0.002446931623178338,
#  467: 0.0025152017484215963,
#  207: 0.0032552854464204485,
#  100: 0.0017315864647889931,
#  468: 0.0033105408507735417,
#  267: 0.0037469783113781244,
#  102: 0.0015711761703825849,
#  384: 0.004315816861312742,
#  103: 0.0029734947031039593,
#  353: 0.0023660730255192384,
#  463: 0.00323438202981619,
#  104: 0.001220619261199344,
#  105: 0.0010146803768735124,
#  422: 0.0031813850231385632,
#  108: 0.0015711761703825849,
#  110: 0.0009861076928519854,
#  213: 0.002019150906343265,
#  279: 0.001031131335844212,
#  136: 0.0024038179596975353,
#  436: 0.0017230571494065191,
#  112: 0.0029219639217518507,
#  440: 0.003637170563979212,
#  456: 0.002890862855139182,
#  324: 0.0011665871868600404,
#  114: 0.0013294681508462588,
#  327: 0.003490916758381904,
#  115: 0.0012407446867007679,
#  344: 0.0021226428376238606,
#  116: 0.0024619838227385826,
#  322: 0.001800324383226237,
#  187: 0.002396951400899916,
#  310: 0.0023965688597265486,
#  117: 0.0032068220150732927,
#  201: 0.0016412240913708956,
#  131: 0.0025807942350995258,
#  265: 0.003880458349621442,
#  241: 0.0018354571811281728,
#  118: 0.0017427162135657194,
#  203: 0.0032865766022139326,
#  387: 0.0031293134785763703,
#  297: 0.003413602392520774,
#  125: 0.0017123314758741872,
#  240: 0.003090804627291917,
#  126: 0.0017952606825814466,
#  285: 0.0041338179525562705,
#  238: 0.001774143039949342,
#  128: 0.003115219360064556,
#  378: 0.0016629006850998017,
#  183: 0.001757582996290734,
#  130: 0.001827471464509332,
#  325: 0.0035633380945264224,
#  419: 0.002811923699955489,
#  228: 0.0020359381570304756,
#  304: 0.0011840830218269622,
#  484: 0.0021114034720333447,
#  135: 0.0013479772700273889,
#  364: 0.0023736572066587877,
#  359: 0.0017758344292147905,
#  138: 0.002325416734408384,
#  220: 0.002145146182050255,
#  150: 0.002526906668130417,
#  143: 0.0017287078229935547,
#  144: 0.0011299702648879509,
#  145: 0.0027921543373990746,
#  475: 0.001926306113449902,
#  146: 0.0012086254028872575,
#  147: 0.0018036695632409768,
#  148: 0.0020178897626372287,
#  294: 0.001196243642210378,
#  191: 0.003897544312162311,
#  149: 0.0013266200219663215,
#  461: 0.002322990002595236,
#  233: 0.0014132523972974654,
#  151: 0.002089419895500395,
#  354: 0.001226693741238208,
#  152: 0.0037820974247931324,
#  374: 0.004426265893526771,
#  447: 0.0023893738503833924,
#  155: 0.0030822326120921503,
#  248: 0.0016808799973126595,
#  156: 0.001203839629034972,
#  157: 0.002032395409288365,
#  209: 0.0019171859639744058,
#  410: 0.0020697739781482885,
#  222: 0.0023614827889571225,
#  159: 0.0017113070445785457,
#  358: 0.0032595070701046825,
#  160: 0.00238264889967418,
#  249: 0.004222849034749991,
#  398: 0.001352935842817166,
#  466: 0.0016183679889485657,
#  460: 0.0009838260322663358,
#  269: 0.0023734754939833264,
#  212: 0.001124048512960659,
#  427: 0.0028097060412210014,
#  431: 0.0032062914629940676,
#  168: 0.004567593724854892,
#  166: 0.0025987917444968253,
#  379: 0.0024381311575026347,
#  179: 0.0014455079928225424,
#  303: 0.001765808914844278,
#  495: 0.0019932545862252258,
#  169: 0.003267051812391026,
#  441: 0.0022585440663537436,
#  180: 0.0012659209016736511,
#  170: 0.0026570137173590564,
#  262: 0.001091372532888532,
#  171: 0.00238264889967418,
#  473: 0.001352935842817166,
#  174: 0.0009982512319220644,
#  175: 0.0012126459817922142,
#  489: 0.00205681953513013,
#  478: 0.0015840956793838187,
#  181: 0.0023572571909508296,
#  472: 0.0016411192303629613,
#  450: 0.0016392192353255667,
#  376: 0.002630244909507092,
#  185: 0.0019081610738300094,
#  487: 0.001854524066720619,
#  311: 0.0012964213457651115,
#  403: 0.0016268242754798774,
#  188: 0.0028055805974702974,
#  488: 0.001795793948456417,
#  307: 0.0011332645452845987,
#  189: 0.001063918733972848,
#  291: 0.0017718196237914417,
#  195: 0.002166184690560278,
#  424: 0.0012591942906579699,
#  397: 0.0024709489732911544,
#  197: 0.0018746612149981444,
#  371: 0.001762403950242715,
#  218: 0.0010134910908764661,
#  202: 0.0017724255471051548,
#  337: 0.0026941512656048455,
#  261: 0.0017427162135657194,
#  204: 0.0010928079579164347,
#  205: 0.001643063324995716,
#  394: 0.001743274987730289,
#  391: 0.0017354990958276032,
#  208: 0.001837039654004011,
#  399: 0.0019053055205159322,
#  210: 0.0017412011842160365,
#  357: 0.0027446531088432514,
#  211: 0.0033954722427884457,
#  225: 0.0017514018561566634,
#  301: 0.0034616609434716767,
#  415: 0.0018641154109546789,
#  257: 0.0018045152372487107,
#  277: 0.0025327827939277438,
#  216: 0.002010378890615848,
#  423: 0.003432595342501498,
#  247: 0.0033253045730633844,
#  217: 0.0022849227141670475,
#  236: 0.0025002543315280758,
#  302: 0.0017113070445785455,
#  275: 0.0013425204430245544,
#  223: 0.0016339324777961382,
#  380: 0.002439897698523014,
#  393: 0.002671500331023437,
#  229: 0.0012792242254981892,
#  464: 0.00221177807902839,
#  230: 0.0020948187850943255,
#  231: 0.0018391046835053051,
#  290: 0.0019085868555053828,
#  375: 0.0014017581764325011,
#  237: 0.002746859324553162,
#  274: 0.0011171928783977056,
#  239: 0.0013296121206696663,
#  355: 0.002334790023698657,
#  437: 0.0019181451462698912,
#  409: 0.0031359334236977666,
#  338: 0.0024561409769411208,
#  331: 0.001280952100729485,
#  313: 0.0030474192221732247,
#  251: 0.0009903614888199812,
#  396: 0.003833479890004651,
#  430: 0.001685172607588188,
#  306: 0.001608334343192621,
#  254: 0.0016684282258995604,
#  361: 0.002450960962343949,
#  256: 0.0009785215865103605,
#  263: 0.0011164444822209807,
#  264: 0.002257336343115124,
#  312: 0.002257336343115124,
#  266: 0.0018925512067350624,
#  408: 0.0016462596294376155,
#  309: 0.0017224549549452552,
#  270: 0.0028557804126966915,
#  417: 0.003681975521305509,
#  443: 0.0017872495961966557,
#  366: 0.0011479397791553606,
#  271: 0.0018546487143280442,
#  406: 0.003317746321125253,
#  295: 0.0016458047592592482,
#  429: 0.0012630876304221019,
#  280: 0.0013294681508462588,
#  281: 0.0019102539033480199,
#  283: 0.0012850224093350028,
#  288: 0.0022274897988121337,
#  284: 0.002257336343115124,
#  455: 0.002257336343115124,
#  287: 0.0019362060995005482,
#  452: 0.0018287576198994743,
#  485: 0.002366724046059256,
#  444: 0.0010744110883470792,
#  315: 0.0012866237653343007,
#  462: 0.0022297015507613442,
#  316: 0.002257336343115124,
#  318: 0.002257336343115124,
#  317: 0.0012586242798275434,
#  420: 0.0017982838570540763,
#  365: 0.0027776634280349314,
#  330: 0.0011208200971682056,
#  332: 0.0023304934981800995,
#  433: 0.0018445740961749702,
#  348: 0.0013822927280969569,
#  343: 0.002257336343115124,
#  350: 0.002257336343115124,
#  346: 0.0011353714422919416,
#  349: 0.002817188759993083,
#  351: 0.0017583078890207214,
#  363: 0.0010280292514425573,
#  368: 0.0016852536568489262,
#  421: 0.002039372901181008,
#  390: 0.0010836326499355797,
#  377: 0.0011262322323615124,
#  490: 0.002362416936239799,
#  381: 0.0013540891826437727,
#  458: 0.0015711761703825849,
#  494: 0.002335731342602547,
#  404: 0.0016058224033960338,
#  418: 0.0011860043831700734,
#  457: 0.0011116313810435512,
#  465: 0.0011457181956592735}

# %% [markdown]
# # Network visualization with Netwulf
#
# It's a very new package (right now version v0.1.4) developed by Ben Maier and Ulf Aslak, so use with caution: https://pypi.org/project/netwulf/
#
# That being said, many people are already using it because of its easy controls and Jupyter notebook integration.
# Install: `pip install netwulf`

# %%
import netwulf as wulf

G = nx.barabasi_albert_graph(100,m=1)
stylized_network, config = wulf.visualize(G)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-67-eabe900a102d> in <module>
# ----> 1 import netwulf as wulf
#       2
#       3 G = nx.barabasi_albert_graph(100,m=1)
#       4 stylized_network, config = wulf.visualize(G)
#
# ModuleNotFoundError: No module named 'netwulf'

# %% [markdown]
# # The End
#
# **Source**
#
# This notebook was adapted from:
# * A network science class by Sean Cornelius and Emma Thompson
# * Introduction to Data Science and Visualization by James Bagrow
# * Introduction to Data Science by Michael Szell
